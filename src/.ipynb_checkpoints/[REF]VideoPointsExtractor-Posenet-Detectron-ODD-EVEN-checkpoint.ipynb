# %%
#if everything is correctly installed...
# A1. drink water.
# A2. eat meal/snack.
# A7. throw.
# A8. sitting down.
# A9. standing up (from sitting position).
# A23. hand waving.
# A31. pointing to something with finger.
# A38. salute.
# A49. use a fan (with hand or paper)/feeling warm.
# ACTION_LABEL_SET = ["A001","A002","A007","A008","A009","A031","A049","A023"]

### FROME thesis of Senesi
# A6. pickup
# A7. throw. ## common
# A8. sitting down. ## common
# A9. standing up.  ## common
# A23. hand waving. ## common
# A24. kicking something.
# A26. hopping (one foot jumping).
# A27. jump up.
# A31. pointing to something. ## common
# A35. nod head/bow.
# ACTION_LABEL_SET = ["A006","A024","A026","A027","A035"]

PARSE_ODD = False

STOP_AT_9AM = True

ALREADY_PARSED_ACTION = [
    "A001","A002","A006","A007","A008",
    "A009","A023","A024","A026","A027",
    "A031","A049","A035"]

ACTION_LABEL_SET = ["A{:03d}".format(i) for i in range(1,61) if "A{:03d}".format(i) not in ALREADY_PARSED_ACTION]

PROJECT_FOLDER = "/data/students_home/amoscatelli/Desktop/actionAnalysis"
RESULT_FOLDER = PROJECT_FOLDER+"/inputData/"
dataset_folder = "/data/datasets/NTURGBD"
video_name_format = "S{:3d}C{:3d}P{:3d}R{:3d}A{:3d}_rgb.avi" #Setup-Camera-Performer-Replication-Action

# %%
import os
# os.environ['PATH'] = "/sbin:/bin:/usr/bin:/usr/local/bin:/snap/bin:/usr/lib/jvm/java-8-oracle/bin:/usr/lib/jvm/java-8-oracle/db/bin:/usr/lib/jvm/java-8-oracle/jre/bin:/usr/lib/jvm/java-8-oracle/bin:/usr/lib/jvm/java-8-oracle/db/bin:/usr/lib/jvm/java-8-oracle/jre/bin"
# os.environ['PATH'] = PROJECT_FOLDER+"/miniconda3/bin:" + os.environ['PATH'] #need to change PATH for PoseNet
os.environ['PATH']
# Out:
# '/data/students_home/amoscatelli/.local/bin:/data/students_home/amoscatelli/Desktop/actionAnalysis/miniconda3/bin:/data/students_home/amoscatelli/Desktop/actionAnalysis/miniconda3/condabin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/usr/games:/usr/local/games:/usr/local/cuda/bin:/snap/bin:/usr/lib/jvm/java-8-oracle/bin:/usr/lib/jvm/java-8-oracle/db/bin:/usr/lib/jvm/java-8-oracle/jre/bin'

# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "2"

# %%
# TensorFlow logger level
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '1' 
# 0 = all messages are logged (default behavior)
# 1 = INFO messages are not printed
# 2 = INFO and WARNING messages are not printed
# 3 = INFO, WARNING, and ERROR messages are not printed

# %% [markdown]
# Extracting related video name files

# %%
# SEED = 1234
import os
import random
from os import listdir, scandir
from os.path import isfile, isdir, join, exists
import parse

setupFolders = [f for f in listdir(dataset_folder) if isdir(join(dataset_folder, f)) and f[:13]=="nturgbd_rgb_s"]
# print(setupFolders)
fileNames = []
fileEntries = []
for folder in setupFolders:
    setupeEntryFiles = [f for f in scandir(join(dataset_folder,folder,"nturgb+d_rgb/")) 
                       if isfile(join(dataset_folder,folder,"nturgb+d_rgb/",f)) 
                       and any(label in f.name for label in ACTION_LABEL_SET)]
    fileEntries += setupeEntryFiles
    
#     fileNames.append([f for f in listdir(join(dataset_folder,folder,"nturgb+d_rgb/")) 
#                        if isfile(join(dataset_folder,folder,"nturgb+d_rgb/",f)) 
#                        and any(label in f for label in ACTION_LABEL_SET)])
                       
    fileNames.append([f.name for f in setupeEntryFiles])
        
fileNames = sum(fileNames, []) #making it in 1-row
print("Videos for choosen actions:", len(fileNames))

if PARSE_ODD:
    print("parsing ODD actions")
    fileNames = [f for f in fileNames if parse.parse(video_name_format, f)[4]%2==1]
else:
    print("parsing EVEN actions")
    fileNames = [f for f in fileNames if parse.parse(video_name_format, f)[4]%2==0]
    
print(len(fileNames),"video to parse") 
# random.seed(SEED)
# random.shuffle(fileNames)
# Out:
# Videos for choosen actions: 44556
# parsing EVEN actions
# 23700 video to parse

# %%
#ordinati per azione
import parse
fileNames.sort(key=lambda name:parse.parse(video_name_format, name)[4])

# %%
fileNames[900:]
# Out:
# ['S014C001P027R001A004_rgb.avi',
#  'S014C001P025R002A004_rgb.avi',
#  'S014C001P007R002A004_rgb.avi',
#  'S014C002P039R002A004_rgb.avi',
#  'S014C002P008R001A004_rgb.avi',
#  'S014C002P037R001A004_rgb.avi',
#  'S014C001P015R002A004_rgb.avi',
#  'S014C003P007R002A004_rgb.avi',
#  'S014C001P017R002A004_rgb.avi',
#  'S014C003P039R002A004_rgb.avi',
#  'S014C003P027R002A004_rgb.avi',
#  'S014C003P015R002A004_rgb.avi',
#  'S014C002P007R001A004_rgb.avi',
#  'S014C002P037R002A004_rgb.avi',
#  'S014C003P008R002A004_rgb.avi',
#  'S014C003P037R001A004_rgb.avi',
#  'S014C002P025R001A004_rgb.avi',
#  'S014C002P019R001A004_rgb.avi',
#  'S014C003P027R001A004_rgb.avi',
#  'S014C001P019R001A004_rgb.avi',
#  'S014C001P025R001A004_rgb.avi',
#  'S014C003P017R002A004_rgb.avi',
#  'S014C002P025R002A004_rgb.avi',
#  'S014C002P039R001A004_rgb.avi',
#  'S014C002P008R002A004_rgb.avi',
#  'S014C003P015R001A004_rgb.avi',
#  'S014C003P025R002A004_rgb.avi',
#  'S014C001P019R002A004_rgb.avi',
#  'S014C001P039R002A004_rgb.avi',
#  'S014C002P019R002A004_rgb.avi',
#  'S014C001P037R002A004_rgb.avi',
#  'S014C003P008R001A004_rgb.avi',
#  'S014C001P008R001A004_rgb.avi',
#  'S014C001P017R001A004_rgb.avi',
#  'S014C002P027R002A004_rgb.avi',
#  'S014C002P015R001A004_rgb.avi',
#  'S014C002P027R001A004_rgb.avi',
#  'S014C003P039R001A004_rgb.avi',
#  'S014C001P027R002A004_rgb.avi',
#  'S014C003P019R002A004_rgb.avi',
#  'S014C001P015R001A004_rgb.avi',
#  'S014C003P017R001A004_rgb.avi',
#  'S014C001P037R001A004_rgb.avi',
#  'S014C003P025R001A004_rgb.avi',
#  'S014C002P015R002A004_rgb.avi',
#  'S014C001P039R001A004_rgb.avi',
#  'S014C002P007R002A004_rgb.avi',
#  'S014C001P008R002A004_rgb.avi',
#  'S003C001P019R001A010_rgb.avi',
#  'S003C001P008R001A010_rgb.avi',
#  'S003C003P019R001A010_rgb.avi',
#  'S003C002P015R001A010_rgb.avi',
#  'S003C003P007R001A010_rgb.avi',
#  'S003C002P015R002A010_rgb.avi',
#  'S003C003P019R002A010_rgb.avi',
#  'S003C001P017R002A010_rgb.avi',
#  'S003C002P017R002A010_rgb.avi',
#  'S003C001P008R002A010_rgb.avi',
#  'S003C002P002R002A010_rgb.avi',
#  'S003C002P008R002A010_rgb.avi',
#  'S003C002P018R001A010_rgb.avi',
#  'S003C002P001R001A010_rgb.avi',
#  'S003C003P001R002A010_rgb.avi',
#  'S003C002P019R002A010_rgb.avi',
#  'S003C001P015R001A010_rgb.avi',
#  'S003C002P008R001A010_rgb.avi',
#  'S003C001P016R001A010_rgb.avi',
#  'S003C003P008R002A010_rgb.avi',
#  'S003C001P016R002A010_rgb.avi',
#  'S003C003P018R002A010_rgb.avi',
#  'S003C002P017R001A010_rgb.avi',
#  'S003C001P007R002A010_rgb.avi',
#  'S003C002P016R001A010_rgb.avi',
#  'S003C001P007R001A010_rgb.avi',
#  'S003C003P016R002A010_rgb.avi',
#  'S003C001P018R002A010_rgb.avi',
#  'S003C003P008R001A010_rgb.avi',
#  'S003C003P015R002A010_rgb.avi',
#  'S003C003P016R001A010_rgb.avi',
#  'S003C001P001R002A010_rgb.avi',
#  'S003C003P017R001A010_rgb.avi',
#  'S003C002P019R001A010_rgb.avi',
#  'S003C002P001R002A010_rgb.avi',
#  'S003C001P002R001A010_rgb.avi',
#  'S003C001P001R001A010_rgb.avi',
#  'S003C003P002R001A010_rgb.avi',
#  'S003C001P017R001A010_rgb.avi',
#  'S003C003P018R001A010_rgb.avi',
#  'S003C001P018R001A010_rgb.avi',
#  'S003C003P015R001A010_rgb.avi',
#  'S003C002P007R002A010_rgb.avi',
#  'S003C002P018R002A010_rgb.avi',
#  'S003C003P002R002A010_rgb.avi',
#  'S003C002P007R001A010_rgb.avi',
#  'S003C002P016R002A010_rgb.avi',
#  'S003C001P002R002A010_rgb.avi',
#  'S003C003P017R002A010_rgb.avi',
#  'S003C001P019R002A010_rgb.avi',
#  'S003C003P001R001A010_rgb.avi',
#  'S003C003P007R002A010_rgb.avi',
#  'S003C002P002R001A010_rgb.avi',
#  'S003C001P015R002A010_rgb.avi',
#  'S008C001P033R001A010_rgb.avi',
#  'S008C002P001R002A010_rgb.avi',
#  'S008C001P035R002A010_rgb.avi',
#  'S008C001P008R001A010_rgb.avi',
#  'S008C001P007R002A010_rgb.avi',
#  'S008C002P034R002A010_rgb.avi',
#  'S008C003P031R002A010_rgb.avi',
#  'S008C003P019R002A010_rgb.avi',
#  'S008C003P025R002A010_rgb.avi',
#  'S008C001P015R002A010_rgb.avi',
#  'S008C003P001R001A010_rgb.avi',
#  'S008C003P008R001A010_rgb.avi',
#  'S008C001P025R001A010_rgb.avi',
#  'S008C003P034R002A010_rgb.avi',
#  'S008C002P019R001A010_rgb.avi',
#  'S008C002P034R001A010_rgb.avi',
#  'S008C001P030R002A010_rgb.avi',
#  'S008C003P033R001A010_rgb.avi',
#  'S008C002P036R001A010_rgb.avi',
#  'S008C001P019R001A010_rgb.avi',
#  'S008C001P015R001A010_rgb.avi',
#  'S008C002P025R001A010_rgb.avi',
#  'S008C001P001R001A010_rgb.avi',
#  'S008C001P034R001A010_rgb.avi',
#  'S008C001P032R001A010_rgb.avi',
#  'S008C001P034R002A010_rgb.avi',
#  'S008C003P036R002A010_rgb.avi',
#  'S008C002P031R002A010_rgb.avi',
#  'S008C002P015R001A010_rgb.avi',
#  'S008C003P035R002A010_rgb.avi',
#  'S008C001P007R001A010_rgb.avi',
#  'S008C002P007R002A010_rgb.avi',
#  'S008C002P033R001A010_rgb.avi',
#  'S008C002P030R001A010_rgb.avi',
#  'S008C002P033R002A010_rgb.avi',
#  'S008C003P001R002A010_rgb.avi',
#  'S008C001P029R001A010_rgb.avi',
#  'S008C001P036R002A010_rgb.avi',
#  'S008C003P015R001A010_rgb.avi',
#  'S008C002P035R002A010_rgb.avi',
#  'S008C003P007R001A010_rgb.avi',
#  'S008C002P008R001A010_rgb.avi',
#  'S008C001P033R002A010_rgb.avi',
#  'S008C001P036R001A010_rgb.avi',
#  'S008C002P029R001A010_rgb.avi',
#  'S008C003P035R001A010_rgb.avi',
#  'S008C003P029R001A010_rgb.avi',
#  'S008C001P035R001A010_rgb.avi',
#  'S008C001P001R002A010_rgb.avi',
#  'S008C001P029R002A010_rgb.avi',
#  'S008C002P030R002A010_rgb.avi',
#  'S008C003P015R002A010_rgb.avi',
#  'S008C002P015R002A010_rgb.avi',
#  'S008C003P030R001A010_rgb.avi',
#  'S008C003P031R001A010_rgb.avi',
#  'S008C002P019R002A010_rgb.avi',
#  'S008C003P030R002A010_rgb.avi',
#  'S008C002P031R001A010_rgb.avi',
#  'S008C002P007R001A010_rgb.avi',
#  'S008C001P032R002A010_rgb.avi',
#  'S008C003P032R002A010_rgb.avi',
#  'S008C002P036R002A010_rgb.avi',
#  'S008C002P029R002A010_rgb.avi',
#  'S008C003P029R002A010_rgb.avi',
#  'S008C002P035R001A010_rgb.avi',
#  'S008C002P032R001A010_rgb.avi',
#  'S008C002P032R002A010_rgb.avi',
#  'S008C003P032R001A010_rgb.avi',
#  'S008C001P025R002A010_rgb.avi',
#  'S008C003P034R001A010_rgb.avi',
#  'S008C001P008R002A010_rgb.avi',
#  'S008C003P025R001A010_rgb.avi',
#  'S008C002P025R002A010_rgb.avi',
#  'S008C003P008R002A010_rgb.avi',
#  'S008C003P007R002A010_rgb.avi',
#  'S008C001P019R002A010_rgb.avi',
#  'S008C003P036R001A010_rgb.avi',
#  'S008C001P030R001A010_rgb.avi',
#  'S008C002P008R002A010_rgb.avi',
#  'S008C003P033R002A010_rgb.avi',
#  'S008C001P031R002A010_rgb.avi',
#  'S008C001P031R001A010_rgb.avi',
#  'S008C002P001R001A010_rgb.avi',
#  'S008C003P019R001A010_rgb.avi',
#  'S009C001P007R001A010_rgb.avi',
#  'S009C002P017R002A010_rgb.avi',
#  'S009C001P015R001A010_rgb.avi',
#  'S009C002P015R002A010_rgb.avi',
#  'S009C001P007R002A010_rgb.avi',
#  'S009C002P025R001A010_rgb.avi',
#  'S009C002P019R002A010_rgb.avi',
#  'S009C002P008R002A010_rgb.avi',
#  'S009C003P016R002A010_rgb.avi',
#  'S009C002P007R002A010_rgb.avi',
#  'S009C003P016R001A010_rgb.avi',
#  'S009C003P007R002A010_rgb.avi',
#  'S009C001P015R002A010_rgb.avi',
#  'S009C001P019R001A010_rgb.avi',
#  'S009C002P015R001A010_rgb.avi',
#  'S009C003P008R001A010_rgb.avi',
#  'S009C001P016R002A010_rgb.avi',
#  'S009C001P025R002A010_rgb.avi',
#  'S009C001P017R002A010_rgb.avi',
#  'S009C003P017R002A010_rgb.avi',
#  'S009C003P015R002A010_rgb.avi',
#  'S009C001P008R002A010_rgb.avi',
#  'S009C001P019R002A010_rgb.avi',
#  'S009C002P017R001A010_rgb.avi',
#  'S009C003P019R002A010_rgb.avi',
#  'S009C002P008R001A010_rgb.avi',
#  'S009C002P025R002A010_rgb.avi',
#  'S009C003P015R001A010_rgb.avi',
#  'S009C003P008R002A010_rgb.avi',
#  'S009C003P025R001A010_rgb.avi',
#  'S009C001P017R001A010_rgb.avi',
#  'S009C001P016R001A010_rgb.avi',
#  'S009C003P007R001A010_rgb.avi',
#  'S009C003P019R001A010_rgb.avi',
#  'S009C001P008R001A010_rgb.avi',
#  'S009C002P016R001A010_rgb.avi',
#  'S009C001P025R001A010_rgb.avi',
#  'S009C002P016R002A010_rgb.avi',
#  'S009C002P019R001A010_rgb.avi',
#  'S009C003P025R002A010_rgb.avi',
#  'S009C002P007R001A010_rgb.avi',
#  'S009C003P017R001A010_rgb.avi',
#  'S005C003P017R001A010_rgb.avi',
#  'S005C002P004R001A010_rgb.avi',
#  'S005C001P013R002A010_rgb.avi',
#  'S005C003P004R001A010_rgb.avi',
#  'S005C002P004R002A010_rgb.avi',
#  'S005C001P015R002A010_rgb.avi',
#  'S005C001P004R001A010_rgb.avi',
#  'S005C003P016R001A010_rgb.avi',
#  'S005C001P017R002A010_rgb.avi',
#  'S005C003P013R001A010_rgb.avi',
#  'S005C003P010R001A010_rgb.avi',
#  'S005C003P004R002A010_rgb.avi',
#  'S005C001P017R001A010_rgb.avi',
#  'S005C001P004R002A010_rgb.avi',
#  'S005C002P016R001A010_rgb.avi',
#  'S005C002P013R002A010_rgb.avi',
#  'S005C002P010R001A010_rgb.avi',
#  'S005C002P018R002A010_rgb.avi',
#  'S005C003P021R001A010_rgb.avi',
#  'S005C003P018R001A010_rgb.avi',
#  'S005C003P015R002A010_rgb.avi',
#  'S005C003P021R002A010_rgb.avi',
#  'S005C001P010R002A010_rgb.avi',
#  'S005C001P016R001A010_rgb.avi',
#  'S005C003P013R002A010_rgb.avi',
#  'S005C002P017R001A010_rgb.avi',
#  'S005C002P021R001A010_rgb.avi',
#  'S005C002P017R002A010_rgb.avi',
#  'S005C003P017R002A010_rgb.avi',
#  'S005C002P016R002A010_rgb.avi',
#  'S005C003P016R002A010_rgb.avi',
#  'S005C001P013R001A010_rgb.avi',
#  'S005C003P015R001A010_rgb.avi',
#  'S005C001P018R002A010_rgb.avi',
#  'S005C002P015R001A010_rgb.avi',
#  'S005C001P016R002A010_rgb.avi',
#  'S005C003P018R002A010_rgb.avi',
#  'S005C002P021R002A010_rgb.avi',
#  'S005C001P015R001A010_rgb.avi',
#  'S005C002P018R001A010_rgb.avi',
#  'S005C003P010R002A010_rgb.avi',
#  'S005C002P013R001A010_rgb.avi',
#  'S005C002P015R002A010_rgb.avi',
#  'S005C001P021R002A010_rgb.avi',
#  'S005C001P010R001A010_rgb.avi',
#  'S005C001P018R001A010_rgb.avi',
#  'S005C002P010R002A010_rgb.avi',
#  'S005C001P021R001A010_rgb.avi',
#  'S013C003P037R002A010_rgb.avi',
#  'S013C002P025R002A010_rgb.avi',
#  'S013C001P025R002A010_rgb.avi',
#  'S013C003P016R001A010_rgb.avi',
#  'S013C002P025R001A010_rgb.avi',
#  'S013C001P037R001A010_rgb.avi',
#  'S013C003P037R001A010_rgb.avi',
#  'S013C001P016R001A010_rgb.avi',
#  'S013C003P016R002A010_rgb.avi',
#  'S013C001P017R001A010_rgb.avi',
#  'S013C002P027R002A010_rgb.avi',
#  'S013C002P018R002A010_rgb.avi',
#  'S013C001P027R001A010_rgb.avi',
#  'S013C002P019R002A010_rgb.avi',
#  'S013C003P007R001A010_rgb.avi',
#  'S013C003P008R001A010_rgb.avi',
#  'S013C001P019R002A010_rgb.avi',
#  'S013C001P008R001A010_rgb.avi',
#  'S013C002P037R002A010_rgb.avi',
#  'S013C002P017R001A010_rgb.avi',
#  'S013C002P028R001A010_rgb.avi',
#  'S013C002P018R001A010_rgb.avi',
#  'S013C001P028R002A010_rgb.avi',
#  'S013C003P018R002A010_rgb.avi',
#  'S013C003P019R001A010_rgb.avi',
#  'S013C001P028R001A010_rgb.avi',
#  'S013C003P025R002A010_rgb.avi',
#  'S013C002P028R002A010_rgb.avi',
#  'S013C003P028R002A010_rgb.avi',
#  'S013C002P007R001A010_rgb.avi',
#  'S013C001P018R001A010_rgb.avi',
#  'S013C001P037R002A010_rgb.avi',
#  'S013C002P007R002A010_rgb.avi',
#  'S013C002P019R001A010_rgb.avi',
#  'S013C001P018R002A010_rgb.avi',
#  'S013C002P015R001A010_rgb.avi',
#  'S013C003P018R001A010_rgb.avi',
#  'S013C001P015R001A010_rgb.avi',
#  'S013C001P025R001A010_rgb.avi',
#  'S013C002P016R002A010_rgb.avi',
#  'S013C002P015R002A010_rgb.avi',
#  'S013C002P027R001A010_rgb.avi',
#  'S013C001P015R002A010_rgb.avi',
#  'S013C001P008R002A010_rgb.avi',
#  'S013C003P007R002A010_rgb.avi',
#  'S013C002P016R001A010_rgb.avi',
#  'S013C002P008R002A010_rgb.avi',
#  'S013C003P019R002A010_rgb.avi',
#  'S013C002P037R001A010_rgb.avi',
#  'S013C001P017R002A010_rgb.avi',
#  'S013C003P017R002A010_rgb.avi',
#  'S013C002P008R001A010_rgb.avi',
#  'S013C002P017R002A010_rgb.avi',
#  'S013C003P015R001A010_rgb.avi',
#  'S013C003P028R001A010_rgb.avi',
#  'S013C003P025R001A010_rgb.avi',
#  'S013C003P027R002A010_rgb.avi',
#  'S013C001P019R001A010_rgb.avi',
#  'S013C003P008R002A010_rgb.avi',
#  'S013C003P027R001A010_rgb.avi',
#  'S013C001P016R002A010_rgb.avi',
#  'S013C003P015R002A010_rgb.avi',
#  'S013C001P007R001A010_rgb.avi',
#  'S013C001P027R002A010_rgb.avi',
#  'S013C003P017R001A010_rgb.avi',
#  'S013C001P007R002A010_rgb.avi',
#  'S001C001P004R001A010_rgb.avi',
#  'S001C002P006R002A010_rgb.avi',
#  'S001C003P002R001A010_rgb.avi',
#  'S001C001P007R001A010_rgb.avi',
#  'S001C003P007R002A010_rgb.avi',
#  'S001C003P005R001A010_rgb.avi',
#  'S001C002P003R002A010_rgb.avi',
#  'S001C003P005R002A010_rgb.avi',
#  'S001C001P007R002A010_rgb.avi',
#  'S001C003P008R002A010_rgb.avi',
#  'S001C002P006R001A010_rgb.avi',
#  'S001C002P008R002A010_rgb.avi',
#  'S001C002P002R002A010_rgb.avi',
#  'S001C003P006R002A010_rgb.avi',
#  'S001C001P002R001A010_rgb.avi',
#  'S001C001P002R002A010_rgb.avi',
#  'S001C001P008R001A010_rgb.avi',
#  'S001C003P001R002A010_rgb.avi',
#  'S001C002P001R002A010_rgb.avi',
#  'S001C002P004R001A010_rgb.avi',
#  'S001C001P008R002A010_rgb.avi',
#  'S001C003P008R001A010_rgb.avi',
#  'S001C001P001R001A010_rgb.avi',
#  'S001C002P003R001A010_rgb.avi',
#  'S001C001P003R001A010_rgb.avi',
#  'S001C001P006R002A010_rgb.avi',
#  'S001C001P004R002A010_rgb.avi',
#  'S001C001P005R002A010_rgb.avi',
#  'S001C002P007R001A010_rgb.avi',
#  'S001C002P005R001A010_rgb.avi',
#  'S001C003P003R001A010_rgb.avi',
#  'S001C002P001R001A010_rgb.avi',
#  'S001C001P001R002A010_rgb.avi',
#  'S001C001P005R001A010_rgb.avi',
#  'S001C003P004R001A010_rgb.avi',
#  'S001C003P004R002A010_rgb.avi',
#  'S001C002P002R001A010_rgb.avi',
#  'S001C001P003R002A010_rgb.avi',
#  'S001C003P001R001A010_rgb.avi',
#  'S001C003P002R002A010_rgb.avi',
#  'S001C003P006R001A010_rgb.avi',
#  'S001C002P004R002A010_rgb.avi',
#  'S001C002P007R002A010_rgb.avi',
#  'S001C002P008R001A010_rgb.avi',
#  'S001C003P003R002A010_rgb.avi',
#  'S001C001P006R001A010_rgb.avi',
#  'S001C003P007R001A010_rgb.avi',
#  'S001C002P005R002A010_rgb.avi',
#  'S007C002P017R002A010_rgb.avi',
#  'S007C002P001R001A010_rgb.avi',
#  'S007C003P001R002A010_rgb.avi',
#  'S007C001P026R002A010_rgb.avi',
#  'S007C001P025R001A010_rgb.avi',
#  'S007C001P001R001A010_rgb.avi',
#  'S007C001P027R001A010_rgb.avi',
#  'S007C002P001R002A010_rgb.avi',
#  'S007C002P007R002A010_rgb.avi',
#  'S007C003P026R002A010_rgb.avi',
#  'S007C001P018R002A010_rgb.avi',
#  'S007C003P019R001A010_rgb.avi',
#  'S007C003P001R001A010_rgb.avi',
#  'S007C002P016R001A010_rgb.avi',
#  'S007C002P025R002A010_rgb.avi',
#  'S007C003P025R001A010_rgb.avi',
#  'S007C002P017R001A010_rgb.avi',
#  'S007C001P019R001A010_rgb.avi',
#  'S007C003P008R001A010_rgb.avi',
#  'S007C002P008R001A010_rgb.avi',
#  'S007C003P016R001A010_rgb.avi',
#  'S007C002P018R002A010_rgb.avi',
#  'S007C003P019R002A010_rgb.avi',
#  'S007C003P027R002A010_rgb.avi',
#  'S007C001P016R001A010_rgb.avi',
#  'S007C002P025R001A010_rgb.avi',
#  'S007C001P016R002A010_rgb.avi',
#  'S007C001P025R002A010_rgb.avi',
#  'S007C003P018R001A010_rgb.avi',
#  'S007C001P028R002A010_rgb.avi',
#  'S007C003P018R002A010_rgb.avi',
#  'S007C001P018R001A010_rgb.avi',
#  'S007C003P007R002A010_rgb.avi',
#  'S007C001P008R002A010_rgb.avi',
#  'S007C001P017R001A010_rgb.avi',
#  'S007C001P019R002A010_rgb.avi',
#  'S007C002P027R002A010_rgb.avi',
#  'S007C001P008R001A010_rgb.avi',
#  'S007C002P008R002A010_rgb.avi',
#  'S007C002P028R001A010_rgb.avi',
#  'S007C002P027R001A010_rgb.avi',
#  'S007C002P018R001A010_rgb.avi',
#  'S007C003P027R001A010_rgb.avi',
#  'S007C003P026R001A010_rgb.avi',
#  'S007C002P016R002A010_rgb.avi',
#  'S007C002P019R002A010_rgb.avi',
#  'S007C003P017R002A010_rgb.avi',
#  'S007C003P016R002A010_rgb.avi',
#  'S007C002P019R001A010_rgb.avi',
#  'S007C001P028R001A010_rgb.avi',
#  'S007C001P017R002A010_rgb.avi',
#  'S007C001P027R002A010_rgb.avi',
#  'S007C001P015R001A010_rgb.avi',
#  'S007C001P007R001A010_rgb.avi',
#  'S007C003P007R001A010_rgb.avi',
#  'S007C002P026R001A010_rgb.avi',
#  'S007C003P028R001A010_rgb.avi',
#  'S007C002P028R002A010_rgb.avi',
#  'S007C001P026R001A010_rgb.avi',
#  'S007C001P015R002A010_rgb.avi',
#  'S007C003P008R002A010_rgb.avi',
#  'S007C002P026R002A010_rgb.avi',
#  'S007C003P025R002A010_rgb.avi',
#  'S007C003P028R002A010_rgb.avi',
#  'S007C003P015R002A010_rgb.avi',
#  'S007C002P015R001A010_rgb.avi',
#  'S007C001P001R002A010_rgb.avi',
#  'S007C002P007R001A010_rgb.avi',
#  'S007C003P015R001A010_rgb.avi',
#  'S007C002P015R002A010_rgb.avi',
#  'S007C001P007R002A010_rgb.avi',
#  'S007C003P017R001A010_rgb.avi',
#  'S015C001P008R001A010_rgb.avi',
#  'S015C001P037R001A010_rgb.avi',
#  'S015C001P025R001A010_rgb.avi',
#  'S015C002P037R002A010_rgb.avi',
#  'S015C002P025R002A010_rgb.avi',
#  'S015C001P017R002A010_rgb.avi',
#  'S015C002P019R001A010_rgb.avi',
#  'S015C003P037R002A010_rgb.avi',
#  'S015C003P017R002A010_rgb.avi',
#  'S015C003P019R001A010_rgb.avi',
#  'S015C002P025R001A010_rgb.avi',
#  'S015C003P007R002A010_rgb.avi',
#  'S015C003P008R001A010_rgb.avi',
#  'S015C002P015R001A010_rgb.avi',
#  'S015C002P037R001A010_rgb.avi',
#  'S015C003P016R002A010_rgb.avi',
#  'S015C001P016R002A010_rgb.avi',
#  'S015C003P015R001A010_rgb.avi',
#  'S015C003P025R001A010_rgb.avi',
#  'S015C002P008R002A010_rgb.avi',
#  'S015C001P019R001A010_rgb.avi',
#  'S015C003P017R001A010_rgb.avi',
#  'S015C003P025R002A010_rgb.avi',
#  'S015C001P015R001A010_rgb.avi',
#  'S015C002P016R002A010_rgb.avi',
#  'S015C001P007R001A010_rgb.avi',
#  'S015C002P008R001A010_rgb.avi',
#  'S015C003P037R001A010_rgb.avi',
#  'S015C001P008R002A010_rgb.avi',
#  'S015C002P019R002A010_rgb.avi',
#  'S015C001P015R002A010_rgb.avi',
#  'S015C001P025R002A010_rgb.avi',
#  'S015C001P016R001A010_rgb.avi',
#  'S015C002P016R001A010_rgb.avi',
#  'S015C003P008R002A010_rgb.avi',
#  'S015C003P007R001A010_rgb.avi',
#  'S015C001P019R002A010_rgb.avi',
#  'S015C002P007R002A010_rgb.avi',
#  'S015C002P015R002A010_rgb.avi',
#  'S015C002P017R002A010_rgb.avi',
#  'S015C003P015R002A010_rgb.avi',
#  'S015C003P016R001A010_rgb.avi',
#  'S015C002P007R001A010_rgb.avi',
#  'S015C003P019R002A010_rgb.avi',
#  'S015C002P017R001A010_rgb.avi',
#  'S015C001P007R002A010_rgb.avi',
#  'S015C001P037R002A010_rgb.avi',
#  'S015C001P017R001A010_rgb.avi',
#  'S002C001P013R002A010_rgb.avi',
#  'S002C001P007R002A010_rgb.avi',
#  'S002C001P008R002A010_rgb.avi',
#  'S002C002P013R001A010_rgb.avi',
#  'S002C003P003R001A010_rgb.avi',
#  'S002C002P010R002A010_rgb.avi',
#  'S002C003P010R002A010_rgb.avi',
#  'S002C002P011R001A010_rgb.avi',
#  'S002C002P014R001A010_rgb.avi',
#  'S002C001P012R001A010_rgb.avi',
#  'S002C001P003R002A010_rgb.avi',
#  'S002C003P012R001A010_rgb.avi',
#  'S002C003P013R001A010_rgb.avi',
#  'S002C002P009R002A010_rgb.avi',
#  'S002C003P008R001A010_rgb.avi',
#  'S002C002P014R002A010_rgb.avi',
#  'S002C003P014R002A010_rgb.avi',
#  'S002C002P012R001A010_rgb.avi',
#  'S002C001P013R001A010_rgb.avi',
#  'S002C003P012R002A010_rgb.avi',
#  'S002C003P009R001A010_rgb.avi',
#  'S002C001P012R002A010_rgb.avi',
#  'S002C001P009R002A010_rgb.avi',
#  'S002C002P013R002A010_rgb.avi',
#  'S002C002P012R002A010_rgb.avi',
#  'S002C003P010R001A010_rgb.avi',
#  'S002C002P008R002A010_rgb.avi',
#  'S002C001P014R002A010_rgb.avi',
#  'S002C002P007R001A010_rgb.avi',
#  'S002C001P011R001A010_rgb.avi',
#  'S002C001P011R002A010_rgb.avi',
#  'S002C003P008R002A010_rgb.avi',
#  'S002C001P010R001A010_rgb.avi',
#  'S002C001P008R001A010_rgb.avi',
#  'S002C002P007R002A010_rgb.avi',
#  'S002C002P003R001A010_rgb.avi',
#  'S002C003P003R002A010_rgb.avi',
#  'S002C003P011R002A010_rgb.avi',
#  'S002C002P003R002A010_rgb.avi',
#  'S002C002P011R002A010_rgb.avi',
#  'S002C001P014R001A010_rgb.avi',
#  'S002C002P009R001A010_rgb.avi',
#  'S002C003P009R002A010_rgb.avi',
#  'S002C001P007R001A010_rgb.avi',
#  'S002C003P007R002A010_rgb.avi',
#  'S002C001P009R001A010_rgb.avi',
#  'S002C001P003R001A010_rgb.avi',
#  'S002C003P007R001A010_rgb.avi',
#  'S002C003P013R002A010_rgb.avi',
#  'S002C003P014R001A010_rgb.avi',
#  'S002C003P011R001A010_rgb.avi',
#  'S002C002P010R001A010_rgb.avi',
#  'S002C002P008R001A010_rgb.avi',
#  'S002C001P010R002A010_rgb.avi',
#  'S004C001P003R002A010_rgb.avi',
#  'S004C003P020R002A010_rgb.avi',
#  'S004C003P008R001A010_rgb.avi',
#  'S004C003P007R001A010_rgb.avi',
#  'S004C002P008R002A010_rgb.avi',
#  'S004C001P003R001A010_rgb.avi',
#  'S004C003P003R002A010_rgb.avi',
#  'S004C003P003R001A010_rgb.avi',
#  'S004C002P007R001A010_rgb.avi',
#  'S004C002P008R001A010_rgb.avi',
#  'S004C001P020R002A010_rgb.avi',
#  'S004C002P020R002A010_rgb.avi',
#  'S004C003P008R002A010_rgb.avi',
#  'S004C003P020R001A010_rgb.avi',
#  'S004C001P007R002A010_rgb.avi',
#  'S004C001P020R001A010_rgb.avi',
#  'S004C002P003R002A010_rgb.avi',
#  'S004C003P007R002A010_rgb.avi',
#  'S004C002P020R001A010_rgb.avi',
#  'S004C001P008R002A010_rgb.avi',
#  'S004C002P003R001A010_rgb.avi',
#  'S004C001P007R001A010_rgb.avi',
#  'S004C002P007R002A010_rgb.avi',
#  'S004C001P008R001A010_rgb.avi',
#  'S006C001P015R002A010_rgb.avi',
#  'S006C003P023R001A010_rgb.avi',
#  'S006C001P017R002A010_rgb.avi',
#  'S006C002P007R002A010_rgb.avi',
#  'S006C001P016R001A010_rgb.avi',
#  'S006C001P024R001A010_rgb.avi',
#  'S006C002P019R002A010_rgb.avi',
#  'S006C001P022R002A010_rgb.avi',
#  'S006C001P001R001A010_rgb.avi',
#  'S006C002P016R001A010_rgb.avi',
#  'S006C003P016R002A010_rgb.avi',
#  'S006C001P023R001A010_rgb.avi',
#  'S006C002P001R002A010_rgb.avi',
#  'S006C003P001R002A010_rgb.avi',
#  'S006C003P007R001A010_rgb.avi',
#  'S006C001P019R001A010_rgb.avi',
#  'S006C002P008R002A010_rgb.avi',
#  'S006C001P007R002A010_rgb.avi',
#  'S006C002P024R001A010_rgb.avi',
#  'S006C002P015R001A010_rgb.avi',
#  'S006C001P023R002A010_rgb.avi',
#  'S006C003P017R001A010_rgb.avi',
#  'S006C003P024R001A010_rgb.avi',
#  'S006C001P017R001A010_rgb.avi',
#  'S006C002P017R001A010_rgb.avi',
#  'S006C002P017R002A010_rgb.avi',
#  'S006C001P008R002A010_rgb.avi',
#  'S006C003P015R002A010_rgb.avi',
#  'S006C002P007R001A010_rgb.avi',
#  'S006C003P008R001A010_rgb.avi',
#  'S006C003P017R002A010_rgb.avi',
#  'S006C003P001R001A010_rgb.avi',
#  'S006C001P019R002A010_rgb.avi',
#  'S006C003P007R002A010_rgb.avi',
#  'S006C003P022R001A010_rgb.avi',
#  'S006C003P023R002A010_rgb.avi',
#  'S006C001P022R001A010_rgb.avi',
#  'S006C001P016R002A010_rgb.avi',
#  'S006C003P016R001A010_rgb.avi',
#  'S006C001P008R001A010_rgb.avi',
#  'S006C001P024R002A010_rgb.avi',
#  'S006C002P022R002A010_rgb.avi',
#  'S006C002P022R001A010_rgb.avi',
#  'S006C002P024R002A010_rgb.avi',
#  'S006C003P022R002A010_rgb.avi',
#  'S006C002P008R001A010_rgb.avi',
#  'S006C003P008R002A010_rgb.avi',
#  'S006C001P015R001A010_rgb.avi',
#  'S006C001P007R001A010_rgb.avi',
#  'S006C002P019R001A010_rgb.avi',
#  'S006C002P001R001A010_rgb.avi',
#  'S006C003P015R001A010_rgb.avi',
#  'S006C002P023R001A010_rgb.avi',
#  'S006C002P015R002A010_rgb.avi',
#  'S006C002P023R002A010_rgb.avi',
#  'S006C003P024R002A010_rgb.avi',
#  'S006C003P019R002A010_rgb.avi',
#  'S006C001P001R002A010_rgb.avi',
#  'S006C003P019R001A010_rgb.avi',
#  'S006C002P016R002A010_rgb.avi',
#  'S010C001P013R001A010_rgb.avi',
#  'S010C003P013R002A010_rgb.avi',
#  'S010C002P018R002A010_rgb.avi',
#  'S010C002P021R001A010_rgb.avi',
#  'S010C002P013R001A010_rgb.avi',
#  'S010C001P016R001A010_rgb.avi',
#  'S010C003P025R001A010_rgb.avi',
#  'S010C001P021R002A010_rgb.avi',
#  'S010C002P019R001A010_rgb.avi',
#  'S010C003P013R001A010_rgb.avi',
#  'S010C003P008R002A010_rgb.avi',
#  'S010C002P025R001A010_rgb.avi',
#  'S010C001P017R002A010_rgb.avi',
#  'S010C001P021R001A010_rgb.avi',
#  'S010C002P021R002A010_rgb.avi',
#  'S010C001P019R001A010_rgb.avi',
#  'S010C001P007R002A010_rgb.avi',
#  'S010C002P015R002A010_rgb.avi',
#  'S010C002P019R002A010_rgb.avi',
#  'S010C002P017R001A010_rgb.avi',
#  'S010C001P015R002A010_rgb.avi',
#  'S010C001P015R001A010_rgb.avi',
#  'S010C002P016R001A010_rgb.avi',
#  'S010C003P007R001A010_rgb.avi',
#  'S010C002P025R002A010_rgb.avi',
#  'S010C003P007R002A010_rgb.avi',
#  'S010C002P008R001A010_rgb.avi',
#  'S010C003P015R001A010_rgb.avi',
#  'S010C002P016R002A010_rgb.avi',
#  'S010C001P007R001A010_rgb.avi',
#  'S010C003P016R001A010_rgb.avi',
#  'S010C002P008R002A010_rgb.avi',
#  'S010C001P019R002A010_rgb.avi',
#  'S010C001P025R001A010_rgb.avi',
#  'S010C003P017R001A010_rgb.avi',
#  'S010C003P025R002A010_rgb.avi',
#  'S010C003P015R002A010_rgb.avi',
#  'S010C002P015R001A010_rgb.avi',
#  'S010C002P017R002A010_rgb.avi',
#  'S010C003P017R002A010_rgb.avi',
#  'S010C001P013R002A010_rgb.avi',
#  'S010C003P018R002A010_rgb.avi',
#  'S010C003P019R001A010_rgb.avi',
#  'S010C002P007R001A010_rgb.avi',
#  'S010C003P021R001A010_rgb.avi',
#  'S010C001P017R001A010_rgb.avi',
#  'S010C003P021R002A010_rgb.avi',
#  'S010C001P008R001A010_rgb.avi',
#  'S010C003P019R002A010_rgb.avi',
#  'S010C001P025R002A010_rgb.avi',
#  'S010C001P016R002A010_rgb.avi',
#  'S010C002P013R002A010_rgb.avi',
#  'S010C003P016R002A010_rgb.avi',
#  'S010C001P008R002A010_rgb.avi',
#  'S010C002P007R002A010_rgb.avi',
#  'S010C002P018R001A010_rgb.avi',
#  'S010C003P018R001A010_rgb.avi',
#  'S010C003P008R001A010_rgb.avi',
#  'S010C001P018R001A010_rgb.avi',
#  'S010C001P018R002A010_rgb.avi',
#  'S016C001P021R001A010_rgb.avi',
#  'S016C001P019R002A010_rgb.avi',
#  'S016C003P021R001A010_rgb.avi',
#  'S016C003P040R002A010_rgb.avi',
#  'S016C003P019R002A010_rgb.avi',
#  'S016C003P039R002A010_rgb.avi',
#  'S016C002P025R001A010_rgb.avi',
#  'S016C003P040R001A010_rgb.avi',
#  'S016C002P021R002A010_rgb.avi',
#  'S016C003P007R002A010_rgb.avi',
#  'S016C003P025R001A010_rgb.avi',
#  'S016C001P007R002A010_rgb.avi',
#  'S016C001P025R001A010_rgb.avi',
#  'S016C003P008R001A010_rgb.avi',
#  'S016C001P039R001A010_rgb.avi',
#  'S016C002P007R001A010_rgb.avi',
#  'S016C003P008R002A010_rgb.avi',
#  'S016C002P039R001A010_rgb.avi',
#  'S016C002P039R002A010_rgb.avi',
#  'S016C001P008R001A010_rgb.avi',
#  'S016C002P019R002A010_rgb.avi',
#  'S016C001P008R002A010_rgb.avi',
#  'S016C003P039R001A010_rgb.avi',
#  'S016C001P021R002A010_rgb.avi',
#  'S016C002P021R001A010_rgb.avi',
#  'S016C001P025R002A010_rgb.avi',
#  'S016C001P040R002A010_rgb.avi',
#  'S016C002P040R001A010_rgb.avi',
#  'S016C003P021R002A010_rgb.avi',
#  'S016C002P008R001A010_rgb.avi',
#  'S016C003P007R001A010_rgb.avi',
#  'S016C001P019R001A010_rgb.avi',
#  'S016C003P019R001A010_rgb.avi',
#  'S016C001P007R001A010_rgb.avi',
#  'S016C002P040R002A010_rgb.avi',
#  'S016C001P039R002A010_rgb.avi',
#  'S016C003P025R002A010_rgb.avi',
#  'S016C002P007R002A010_rgb.avi',
#  'S016C001P040R001A010_rgb.avi',
#  'S016C002P025R002A010_rgb.avi',
#  'S016C002P008R002A010_rgb.avi',
#  'S016C002P019R001A010_rgb.avi',
#  'S017C001P007R002A010_rgb.avi',
#  'S017C001P009R001A010_rgb.avi',
#  'S017C002P009R001A010_rgb.avi',
#  'S017C002P007R002A010_rgb.avi',
#  'S017C003P008R002A010_rgb.avi',
#  'S017C003P009R001A010_rgb.avi',
#  'S017C001P007R001A010_rgb.avi',
#  'S017C003P008R001A010_rgb.avi',
#  'S017C002P016R001A010_rgb.avi',
#  'S017C002P015R001A010_rgb.avi',
#  'S017C003P016R002A010_rgb.avi',
#  'S017C001P020R002A010_rgb.avi',
#  'S017C002P008R002A010_rgb.avi',
#  'S017C003P015R001A010_rgb.avi',
#  'S017C003P007R001A010_rgb.avi',
#  'S017C001P016R002A010_rgb.avi',
#  'S017C002P017R001A010_rgb.avi',
#  'S017C003P016R001A010_rgb.avi',
#  'S017C001P003R002A010_rgb.avi',
#  'S017C001P020R001A010_rgb.avi',
#  'S017C003P017R001A010_rgb.avi',
#  'S017C002P007R001A010_rgb.avi',
#  'S017C002P003R001A010_rgb.avi',
#  'S017C001P009R002A010_rgb.avi',
#  'S017C003P017R002A010_rgb.avi',
#  'S017C003P003R001A010_rgb.avi',
#  'S017C001P015R002A010_rgb.avi',
#  'S017C002P008R001A010_rgb.avi',
#  'S017C003P020R001A010_rgb.avi',
#  'S017C002P016R002A010_rgb.avi',
#  'S017C002P015R002A010_rgb.avi',
#  'S017C001P016R001A010_rgb.avi',
#  'S017C002P003R002A010_rgb.avi',
#  'S017C001P015R001A010_rgb.avi',
#  'S017C003P020R002A010_rgb.avi',
#  'S017C001P003R001A010_rgb.avi',
#  'S017C001P017R001A010_rgb.avi',
#  'S017C001P008R002A010_rgb.avi',
#  'S017C002P009R002A010_rgb.avi',
#  'S017C003P009R002A010_rgb.avi',
#  'S017C002P020R001A010_rgb.avi',
#  'S017C003P007R002A010_rgb.avi',
#  'S017C002P017R002A010_rgb.avi',
#  'S017C001P008R001A010_rgb.avi',
#  'S017C001P017R002A010_rgb.avi',
#  'S017C003P003R002A010_rgb.avi',
#  'S017C003P015R002A010_rgb.avi',
#  'S017C002P020R002A010_rgb.avi',
#  'S012C001P008R001A010_rgb.avi',
#  'S012C002P028R002A010_rgb.avi',
#  'S012C001P016R001A010_rgb.avi',
#  'S012C003P028R002A010_rgb.avi',
#  'S012C001P015R002A010_rgb.avi',
#  'S012C002P025R002A010_rgb.avi',
#  'S012C001P017R001A010_rgb.avi',
#  'S012C003P017R001A010_rgb.avi',
#  'S012C002P017R001A010_rgb.avi',
#  'S012C002P027R002A010_rgb.avi',
#  'S012C002P015R001A010_rgb.avi',
#  'S012C002P019R001A010_rgb.avi',
#  'S012C001P028R002A010_rgb.avi',
#  'S012C003P025R002A010_rgb.avi',
#  'S012C002P016R002A010_rgb.avi',
#  'S012C002P018R002A010_rgb.avi',
#  'S012C001P037R002A010_rgb.avi',
#  'S012C003P019R002A010_rgb.avi',
#  'S012C002P019R002A010_rgb.avi',
#  'S012C003P015R001A010_rgb.avi',
#  'S012C003P027R001A010_rgb.avi',
#  'S012C002P015R002A010_rgb.avi',
#  'S012C001P008R002A010_rgb.avi',
#  'S012C002P028R001A010_rgb.avi',
#  'S012C003P007R002A010_rgb.avi',
#  'S012C001P016R002A010_rgb.avi',
#  'S012C002P025R001A010_rgb.avi',
#  'S012C003P028R001A010_rgb.avi',
#  'S012C003P015R002A010_rgb.avi',
#  'S012C003P008R001A010_rgb.avi',
#  'S012C002P018R001A010_rgb.avi',
#  'S012C003P018R002A010_rgb.avi',
#  'S012C002P037R002A010_rgb.avi',
#  'S012C001P019R001A010_rgb.avi',
#  'S012C002P037R001A010_rgb.avi',
#  'S012C001P015R001A010_rgb.avi',
#  'S012C003P018R001A010_rgb.avi',
#  'S012C003P025R001A010_rgb.avi',
#  'S012C003P016R001A010_rgb.avi',
#  'S012C001P025R001A010_rgb.avi',
#  'S012C003P007R001A010_rgb.avi',
#  'S012C002P017R002A010_rgb.avi',
#  'S012C001P037R001A010_rgb.avi',
#  'S012C002P008R002A010_rgb.avi',
#  'S012C003P017R002A010_rgb.avi',
#  'S012C001P018R002A010_rgb.avi',
#  'S012C001P019R002A010_rgb.avi',
#  'S012C002P007R002A010_rgb.avi',
#  'S012C003P008R002A010_rgb.avi',
#  'S012C002P027R001A010_rgb.avi',
#  'S012C002P008R001A010_rgb.avi',
#  'S012C001P025R002A010_rgb.avi',
#  'S012C002P007R001A010_rgb.avi',
#  'S012C001P027R001A010_rgb.avi',
#  'S012C003P037R001A010_rgb.avi',
#  'S012C001P027R002A010_rgb.avi',
#  'S012C003P016R002A010_rgb.avi',
#  'S012C001P028R001A010_rgb.avi',
#  'S012C001P018R001A010_rgb.avi',
#  'S012C003P027R002A010_rgb.avi',
#  'S012C001P017R002A010_rgb.avi',
#  'S012C001P007R001A010_rgb.avi',
#  'S012C003P019R001A010_rgb.avi',
#  'S012C001P007R002A010_rgb.avi',
#  'S012C002P016R001A010_rgb.avi',
#  'S012C003P037R002A010_rgb.avi',
#  'S011C002P007R002A010_rgb.avi',
#  'S011C003P016R002A010_rgb.avi',
#  'S011C001P027R002A010_rgb.avi',
#  'S011C002P019R002A010_rgb.avi',
#  'S011C002P016R001A010_rgb.avi',
#  'S011C002P008R001A010_rgb.avi',
#  'S011C003P015R002A010_rgb.avi',
#  'S011C002P001R002A010_rgb.avi',
#  'S011C002P025R002A010_rgb.avi',
#  'S011C001P015R001A010_rgb.avi',
#  'S011C002P018R002A010_rgb.avi',
#  'S011C001P025R002A010_rgb.avi',
#  'S011C002P028R002A010_rgb.avi',
#  'S011C002P001R001A010_rgb.avi',
#  'S011C002P015R002A010_rgb.avi',
#  'S011C001P017R001A010_rgb.avi',
#  'S011C001P027R001A010_rgb.avi',
#  'S011C001P008R001A010_rgb.avi',
#  'S011C003P028R001A010_rgb.avi',
#  'S011C002P016R002A010_rgb.avi',
#  'S011C003P027R002A010_rgb.avi',
#  'S011C001P028R002A010_rgb.avi',
#  'S011C003P016R001A010_rgb.avi',
#  'S011C002P028R001A010_rgb.avi',
#  'S011C002P002R001A010_rgb.avi',
#  'S011C002P027R002A010_rgb.avi',
#  'S011C003P017R001A010_rgb.avi',
#  'S011C003P038R001A010_rgb.avi',
#  'S011C001P018R001A010_rgb.avi',
#  'S011C002P007R001A010_rgb.avi',
#  'S011C003P008R002A010_rgb.avi',
#  'S011C002P002R002A010_rgb.avi',
#  'S011C001P002R001A010_rgb.avi',
#  'S011C001P019R001A010_rgb.avi',
#  'S011C001P017R002A010_rgb.avi',
#  'S011C003P025R002A010_rgb.avi',
#  'S011C003P027R001A010_rgb.avi',
#  'S011C003P025R001A010_rgb.avi',
#  'S011C002P015R001A010_rgb.avi',
#  'S011C001P007R002A010_rgb.avi',
#  'S011C003P015R001A010_rgb.avi',
#  'S011C002P017R002A010_rgb.avi',
#  'S011C003P019R001A010_rgb.avi',
#  'S011C001P016R002A010_rgb.avi',
#  'S011C003P007R001A010_rgb.avi',
#  'S011C003P001R001A010_rgb.avi',
#  'S011C001P001R001A010_rgb.avi',
#  'S011C003P001R002A010_rgb.avi',
#  'S011C001P018R002A010_rgb.avi',
#  'S011C001P028R001A010_rgb.avi',
#  'S011C003P017R002A010_rgb.avi',
#  'S011C003P018R002A010_rgb.avi',
#  'S011C001P007R001A010_rgb.avi',
#  'S011C002P017R001A010_rgb.avi',
#  'S011C002P038R002A010_rgb.avi',
#  'S011C001P025R001A010_rgb.avi',
#  'S011C003P018R001A010_rgb.avi',
#  'S011C001P008R002A010_rgb.avi',
#  'S011C002P008R002A010_rgb.avi',
#  'S011C002P019R001A010_rgb.avi',
#  'S011C003P019R002A010_rgb.avi',
#  'S011C002P027R001A010_rgb.avi',
#  'S011C003P002R001A010_rgb.avi',
#  'S011C001P016R001A010_rgb.avi',
#  'S011C003P008R001A010_rgb.avi',
#  'S011C001P019R002A010_rgb.avi',
#  'S011C001P001R002A010_rgb.avi',
#  'S011C003P002R002A010_rgb.avi',
#  'S011C001P038R001A010_rgb.avi',
#  'S011C002P038R001A010_rgb.avi',
#  'S011C003P007R002A010_rgb.avi',
#  'S011C001P038R002A010_rgb.avi',
#  'S011C002P018R001A010_rgb.avi',
#  'S011C001P015R002A010_rgb.avi',
#  'S011C002P025R001A010_rgb.avi',
#  'S011C003P038R002A010_rgb.avi',
#  'S011C003P028R002A010_rgb.avi',
#  'S011C001P002R002A010_rgb.avi',
#  'S014C003P037R002A010_rgb.avi',
#  'S014C002P015R002A010_rgb.avi',
#  'S014C001P019R001A010_rgb.avi',
#  'S014C003P037R001A010_rgb.avi',
#  'S014C002P007R001A010_rgb.avi',
#  'S014C002P039R001A010_rgb.avi',
#  'S014C002P027R002A010_rgb.avi',
#  'S014C003P015R002A010_rgb.avi',
#  'S014C001P027R002A010_rgb.avi',
#  'S014C002P015R001A010_rgb.avi',
#  'S014C003P015R001A010_rgb.avi',
#  'S014C003P007R001A010_rgb.avi',
#  'S014C003P008R002A010_rgb.avi',
#  'S014C001P017R001A010_rgb.avi',
#  'S014C001P037R001A010_rgb.avi',
#  'S014C002P025R002A010_rgb.avi',
#  'S014C001P039R002A010_rgb.avi',
#  'S014C002P017R001A010_rgb.avi',
#  'S014C003P025R001A010_rgb.avi',
#  'S014C001P039R001A010_rgb.avi',
#  'S014C003P027R001A010_rgb.avi',
#  'S014C002P008R002A010_rgb.avi',
#  'S014C003P025R002A010_rgb.avi',
#  'S014C002P037R001A010_rgb.avi',
#  'S014C002P007R002A010_rgb.avi',
#  'S014C002P019R002A010_rgb.avi',
#  'S014C003P039R002A010_rgb.avi',
#  'S014C002P008R001A010_rgb.avi',
#  'S014C001P027R001A010_rgb.avi',
#  'S014C002P039R002A010_rgb.avi',
#  'S014C002P037R002A010_rgb.avi',
#  'S014C003P007R002A010_rgb.avi',
#  'S014C002P025R001A010_rgb.avi',
#  'S014C001P025R002A010_rgb.avi',
#  'S014C002P027R001A010_rgb.avi',
#  'S014C003P008R001A010_rgb.avi',
#  'S014C002P019R001A010_rgb.avi',
#  'S014C003P017R002A010_rgb.avi',
#  'S014C001P007R001A010_rgb.avi',
#  'S014C001P015R001A010_rgb.avi',
#  'S014C001P025R001A010_rgb.avi',
#  'S014C001P008R002A010_rgb.avi',
#  'S014C001P007R002A010_rgb.avi',
#  'S014C001P015R002A010_rgb.avi',
#  'S014C001P017R002A010_rgb.avi',
#  'S014C001P008R001A010_rgb.avi',
#  'S014C003P017R001A010_rgb.avi',
#  'S014C001P037R002A010_rgb.avi',
#  'S014C001P019R002A010_rgb.avi',
#  'S014C003P019R001A010_rgb.avi',
#  'S014C003P039R001A010_rgb.avi',
#  'S014C003P019R002A010_rgb.avi',
#  'S014C003P027R002A010_rgb.avi',
#  'S014C002P017R002A010_rgb.avi',
#  'S003C001P016R002A012_rgb.avi',
#  'S003C003P019R001A012_rgb.avi',
#  'S003C003P015R002A012_rgb.avi',
#  'S003C001P007R002A012_rgb.avi',
#  ...]

# %% [markdown]
# Assert that all the concerned videos have dimension (1080, 1920)
#
# is written on the dataset decription: "Video samples have been captured by three Microsoft Kinect V2 cameras concurrently. The resolutions of RGB videos are 1920×1080, depth maps and IR videos are all in 512×424, and 3D skeletal data contains the 3D locations of 25 major body joints at each frame."

# %%
# import cv2
# for i,f in enumerate(fileEntries):
#     if i % 100 == 0:
#         print("{}/{}".format(i,len(fileEntries)))
#     file_path = f.path  # change to your own video path
#     vid = cv2.VideoCapture(file_path)
#     height = vid.get(cv2.CAP_PROP_FRAME_HEIGHT)
#     width = vid.get(cv2.CAP_PROP_FRAME_WIDTH)
#     assert (height==1080 and width==1920)
# print("DONE!")

# %%
from os.path import isfile, isdir, join, exists

# extracting the frames of the passed video file name in output_folder
def extractFrames(file_name, output_folder):
    REQUESTED_FRAMES_PER_SECONDS = 30
    
    setup, camera, performer, replication, action = parse.parse(video_name_format, file_name)
    filePath = join(dataset_folder,"nturgbd_rgb_s{:03d}".format(setup),"nturgb+d_rgb/",file_name)
    
    # Opens the Video file
    video = cv2.VideoCapture(filePath)

    fps = round(video.get(cv2.CAP_PROP_FPS))
    length = int(video.get(cv2.CAP_PROP_FRAME_COUNT))
    width  = int(video.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(video.get(cv2.CAP_PROP_FRAME_HEIGHT))

    print("Original FPS: {}".format(int(fps)))
    print("Requested FPS: {}".format(int(REQUESTED_FRAMES_PER_SECONDS)))
    print("length: {} width: {} height: {}".format(length, width, height))
    frame_ratio_to_keep = max(round(fps/REQUESTED_FRAMES_PER_SECONDS),1)

    print("pick 1 frame every {}".format(int(frame_ratio_to_keep)))

    try:
#         os.mkdir("./temp")
        os.mkdir(output_folder)
    except:
        pass
    
    # !rm $output_folder/* # cleaning output_folder
    
    i = -1
    while(video.isOpened()):
        i+=1
        ret, frame = video.read()
        if(i%frame_ratio_to_keep!=0):
            # print("DISCARDED")
            continue
        # print("PASSED")
        if ret == False:
            # print("FINISHED")
            break
        
        cv2.imwrite(join(output_folder,"frame{:04d}.jpg".format(i)),frame)

    video.release()
    cv2.destroyAllWindows()

# %%
import cv2
import pickle
import torch, torchvision
print(torch.__version__)
# You may need to restart your runtime prior to this, to let your installation take effect
# Some basic setup
# Setup detectron2 logger
import detectron2
from detectron2.utils.logger import setup_logger
setup_logger()

# import some common libraries
import numpy as np
#from google.colab.patches import cv2_imshow

# import some common detectron2 utilities
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2.utils.visualizer import Visualizer
from detectron2.data import MetadataCatalog
# Out:
# 1.4.0+cu100

# %% [markdown]
# retrieve last file analised in case you stop/restart the extaction

# %% [markdown]
# ## checking function

# %%
from os import listdir, scandir

# densePoseModelName = "DensePose_ResNet101_FPN_32x8d_s1x-e2e" 
# densePoseModelName = "DensePose_ResNet101_FPN_s1x-e2e" 
# densePoseModelName = "DensePoseKeyPointsMask_ResNet50_FPN_s1x-e2e" 

detectron2ModelName = "Detectron2-keypoint_rcnn_X_101_32x8d_FPN_3x"
poseNetModelName = "PoseNet-101"

# Return True is the folder is correctly done, False otherwise removing the incorrect subfolders
def checkAndFixFolder(video_folder_name, foldersPerVideo = [detectron2ModelName,poseNetModelName]):   
    result = True
    modelFolderPaths = [f.path for f in scandir(video_folder_name) if isdir(f)]
    modelFolders = [f.split("/")[-1] for f in modelFolderPaths]
    if set(modelFolders) != set(foldersPerVideo):
        print(video_folder_name, "doesn't contain", list(set(foldersPerVideo) - set(modelFolders)))
        result = False
    
    filesPerFolder = list(zip(map(lambda folder: len(listdir(folder)) ,modelFolderPaths),modelFolderPaths)) # take the number of files of each model folder
    if len(filesPerFolder) ==0:
        return result
    maxNumberOfFiles = max(filesPerFolder)[0]
    for numberOfFiles,folderPath in filesPerFolder:
        if numberOfFiles == 0 or numberOfFiles != maxNumberOfFiles:
            print("removing incorrect folder {}".format(folderPath))
            # !rm -r $folderPath
            result = False
            
    return result
    
    
    
#     if len(modelFolderPaths) > 0 :
#         filesInEachFolder = len([f for f in listdir(modelFolderPaths[0])]) # take the number of files of the first model folder
#         for model_folder_path in modelFolderPaths:
#             if filesInEachFolder != len([f for f in listdir(model_folder_path)]): # each model folder must contain the same number of files
#                 print(model_folder_path, "not parsed correctly")
# print("DONE!")

# %%
# checkAndFixFolder("../inputData/S012C003P007R001A023_rgb/")

# %% [markdown]
# ## Extracting points from video frames

# %%
import sys 

def startParsing():
    #### PoseNet config #### 
    poseNetModel = 101 #50, 75, 100, 101
    # os.environ['PATH'] = "/sbin:/bin:/usr/bin:/usr/local/bin:/snap/bin:/usr/lib/jvm/java-8-oracle/bin:/usr/lib/jvm/java-8-oracle/db/bin:/usr/lib/jvm/java-8-oracle/jre/bin:/usr/lib/jvm/java-8-oracle/bin:/usr/lib/jvm/java-8-oracle/db/bin:/usr/lib/jvm/java-8-oracle/jre/bin"
    # os.environ['PATH'] = PROJECT_FOLDER+"/miniconda3/bin:" + os.environ['PATH'] #need to change PATH for PoseNet

    #### DensePose config #### 
    # densePoseModelName = "DensePose_ResNet101_FPN_32x8d_s1x-e2e" #conf -> .yaml weights -> .pkl
    # densePoseModelName = "DensePose_ResNet101_FPN_s1x-e2e" #conf -> .yaml weights -> .pkl
    # densePoseModelName = "DensePoseKeyPointsMask_ResNet50_FPN_s1x-e2e" #conf -> .yaml weights -> .pkl
    # densePoseConfig = densePoseModelName+".yaml"
    # densePoseWeigths = densePoseModelName+".pkl"

    #### Detectron2 config #### 
    cfg = get_cfg()
    detectron2ConfigName = "/detectron2_repo/configs/COCO-Keypoints/keypoint_rcnn_X_101_32x8d_FPN_3x.yaml"
    modelWeightName = "detectron2://COCO-Keypoints/keypoint_rcnn_X_101_32x8d_FPN_3x/139686956/model_final_5ad38f.pkl"
    # detectron2ConfigName = "/detectron2_repo/configs/COCO-Keypoints/keypoint_rcnn_R_50_FPN_3x.yaml"
    # modelWeightsName = "detectron2://COCO-Keypoints/keypoint_rcnn_R_50_FPN_3x/137849621/model_final_a6e10b.pkl"
    cfg.merge_from_file(PROJECT_FOLDER+detectron2ConfigName)
    cfg.MODEL.WEIGHTS = modelWeightName
    cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.4  # set threshold for this model

    # with torch.cuda.device(GPU_CARD):
    predictor = DefaultPredictor(cfg) # Detectron2 predictor
    try:
        for i, file_name in enumerate(fileNames):

            print("############ {}/{} - {} ############".format(i, len(fileNames), file_name))

            video_points_folder_name = RESULT_FOLDER+file_name[:-4] #removing the .avi extension
            if not exists(video_points_folder_name):
                os.mkdir(video_points_folder_name)
    #         else:
    #             ### CHECK ##########
    #             if checkAndFixFolder(video_points_folder_name):
    #                 print("#### already completely parsed ##### ")
    #                 continue

            if checkAndFixFolder(video_points_folder_name):
                    print("#### already completely parsed ##### ")
                    continue

            os.environ['PATH'] = "/sbin:/bin:/usr/bin:/usr/local/bin:/snap/bin:/usr/lib/jvm/java-8-oracle/bin:/usr/lib/jvm/java-8-oracle/db/bin:/usr/lib/jvm/java-8-oracle/jre/bin:/usr/lib/jvm/java-8-oracle/bin:/usr/lib/jvm/java-8-oracle/db/bin:/usr/lib/jvm/java-8-oracle/jre/bin"
            os.environ['PATH'] = PROJECT_FOLDER+"/miniconda3/bin:" + os.environ['PATH'] #need to change PATH for PoseNet

            ######### Extracting frames #########
            temp_folder = "/data/students_home/amoscatelli/Desktop/actionAnalysis/repo/tesiMagistrale/src/temp"
            temp_folder += str("-ODD") if PARSE_ODD else str("-EVEN")
            extractFrames(file_name,temp_folder) # extract the video frames in temp_folder
            framePaths = [f.path for f in os.scandir(temp_folder) if f.is_file() and f.path.endswith('.jpg')]

            ######### POSENET #########
            poseNetFolder = video_points_folder_name+"/PoseNet-"+str(poseNetModel)
            if not exists(poseNetFolder):
                os.mkdir(poseNetFolder)
        #         !export CUDA_VISIBLE_DEVICES=$GPU_CARD && 
                # !cd $PROJECT_FOLDER/posenet-python && python keyPointsLogger.py \
                    --model $poseNetModel \
                    --image_dir $temp_folder \
                    --output_dir $poseNetFolder
            else:
                print("######  video already parsed with PoseNet #####")

            print("######  PoseNet done  #####")


            ######### Detectron2 #########
            print("######  parsing with Detectron2.... #####")
            detectron2Model = detectron2ConfigName.split("/")[-1][:-5]
            detectron2Folder = video_points_folder_name+"/Detectron2-"+str(detectron2Model)
            if not exists(detectron2Folder):
                os.mkdir(detectron2Folder)
                for frame_path in framePaths:
                    outputsFile = frame_path.split("/")[-1][:-4]+".pickle" # e.g.: ./temp/frame0010.jpg --> frame0010.pickle
                    im = cv2.imread(frame_path)      
                    outputs = predictor(im)
                    with open(detectron2Folder+"/"+outputsFile, 'wb') as file_out:
                        pickle.dump(outputs, file_out, protocol=pickle.HIGHEST_PROTOCOL)
            else:
                print("######  video already parsed with Detectron2 #####")

            print("######  Detectron2 done! #####")

        #     ######### DensePose #########
    #         os.environ['PATH'] = "/sbin:/bin:/usr/bin:/usr/local/bin:/snap/bin:/usr/lib/jvm/java-8-oracle/bin:/usr/lib/jvm/java-8-oracle/db/bin:/usr/lib/jvm/java-8-oracle/jre/bin:/usr/lib/jvm/java-8-oracle/bin:/usr/lib/jvm/java-8-oracle/db/bin:/usr/lib/jvm/java-8-oracle/jre/bin"
    #         os.environ['PATH'] = PROJECT_FOLDER+"/anaconda2/bin:" + os.environ['PATH'] #need to change PATH for DensePose

    #         print("######  parsing with DensePose.... #####")
    #         densePoseFolder = video_points_folder_name+"/"+densePoseModelName
    #         if not exists(densePoseFolder):
    #             os.mkdir(densePoseFolder)

    # #             !export CUDA_VISIBLE_DEVICES=$GPU_CARD && 
    #             !cd $PROJECT_FOLDER/DensePose && python2 tools/pointsLogger.py \
    #                 --cfg configs/$densePoseConfig \
    #                 --output-dir $densePoseFolder \
    #                 --image-ext jpg \
    #                 --wts https://dl.fbaipublicfiles.com/densepose/$densePoseWeigths \
    #                 ../src/temp
    #         else:
    #             print("######  video already parsed with DensePose #####") 
    #         print("######  DensePose done! #####")
    except: 
        print(sys.exc_info()[0])
        print("##### Exception occurred while analysing: ", file_name)
    print("DONE!")

# %%
import multiprocessing
from datetime import datetime
import time


stopAt = "04/02/2020 9:00"


dateTimeToStop = datetime.strptime(stopAt, "%d/%m/%Y %H:%M")
now = datetime.now()
differenceInSeconds = int(dateTimeToStop.timestamp()) - int(now.timestamp())

nowReadable = datetime.fromtimestamp(now.timestamp()).strftime("%d/%m/%Y %H:%M:%S")
print("Now is ",nowReadable)
print("Stop at", stopAt, "-> stop in (h:m:s)", datetime.fromtimestamp(differenceInSeconds-60*60).strftime("%H:%M:%S"))
print("Stop in",differenceInSeconds,"seconds")

assert (differenceInSeconds > 0 and differenceInSeconds < 12*60*60), "calmo leone! stai lanciando il programma per più di 12 ore"
    

# Start parsing as a process
p = multiprocessing.Process(target=startParsing)
p.start()


# Wait for moment to stop (in seconds) or until process finishes
p.join(differenceInSeconds)

# If thread is still active
if p.is_alive():
    print("running... let's kill it...")
    # Terminate
    p.terminate()
    p.join()
    # %%javascript
    Jupyter.notebook.session.delete();
# Out:
# Now is  04/02/2020 00:47:37
# Stop at 04/02/2020 9:00 -> stop in (h:m:s) 08:12:23
# Stop in 29543 seconds
# ############ 0/23700 - S003C002P019R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 1/23700 - S003C003P007R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 2/23700 - S003C003P016R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 3/23700 - S003C001P001R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 4/23700 - S003C003P008R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 5/23700 - S003C002P016R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 6/23700 - S003C001P018R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 7/23700 - S003C003P001R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 8/23700 - S003C001P007R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 9/23700 - S003C003P007R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 10/23700 - S003C001P015R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 11/23700 - S003C001P019R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 12/23700 - S003C003P019R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 13/23700 - S003C002P018R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 14/23700 - S003C003P017R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 15/23700 - S003C003P015R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 16/23700 - S003C001P018R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 17/23700 - S003C003P018R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 18/23700 - S003C002P017R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 19/23700 - S003C003P016R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 20/23700 - S003C003P008R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 21/23700 - S003C003P002R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 22/23700 - S003C002P008R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 23/23700 - S003C001P002R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 24/23700 - S003C002P018R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 25/23700 - S003C001P015R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 26/23700 - S003C002P002R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 27/23700 - S003C003P002R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 28/23700 - S003C001P016R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 29/23700 - S003C003P018R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 30/23700 - S003C001P002R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 31/23700 - S003C003P001R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 32/23700 - S003C002P001R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 33/23700 - S003C001P016R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 34/23700 - S003C001P008R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 35/23700 - S003C001P017R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 36/23700 - S003C002P001R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 37/23700 - S003C002P008R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 38/23700 - S003C001P019R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 39/23700 - S003C003P017R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 40/23700 - S003C003P019R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 41/23700 - S003C001P017R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 42/23700 - S003C002P002R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 43/23700 - S003C001P007R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 44/23700 - S003C003P015R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 45/23700 - S003C002P007R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 46/23700 - S003C001P001R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 47/23700 - S003C001P008R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 48/23700 - S003C002P007R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 49/23700 - S003C002P019R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 50/23700 - S003C002P015R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 51/23700 - S003C002P015R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 52/23700 - S003C002P016R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 53/23700 - S003C002P017R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 54/23700 - S008C002P025R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 55/23700 - S008C002P019R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 56/23700 - S008C001P007R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 57/23700 - S008C002P001R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 58/23700 - S008C001P025R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 59/23700 - S008C001P008R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 60/23700 - S008C001P015R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 61/23700 - S008C003P031R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 62/23700 - S008C002P007R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 63/23700 - S008C003P033R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 64/23700 - S008C002P030R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 65/23700 - S008C002P035R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 66/23700 - S008C002P008R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 67/23700 - S008C001P001R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 68/23700 - S008C002P030R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 69/23700 - S008C002P019R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 70/23700 - S008C001P029R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 71/23700 - S008C003P035R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 72/23700 - S008C003P031R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 73/23700 - S008C001P030R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 74/23700 - S008C003P034R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 75/23700 - S008C001P030R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 76/23700 - S008C001P035R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 77/23700 - S008C003P034R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 78/23700 - S008C003P029R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 79/23700 - S008C001P029R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 80/23700 - S008C001P033R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 81/23700 - S008C003P033R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 82/23700 - S008C002P032R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 83/23700 - S008C003P032R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 84/23700 - S008C001P008R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 85/23700 - S008C002P008R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 86/23700 - S008C001P007R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 87/23700 - S008C003P030R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 88/23700 - S008C003P019R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 89/23700 - S008C003P015R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 90/23700 - S008C002P015R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 91/23700 - S008C002P015R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 92/23700 - S008C002P031R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 93/23700 - S008C003P035R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 94/23700 - S008C002P033R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 95/23700 - S008C002P025R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 96/23700 - S008C001P031R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 97/23700 - S008C003P029R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 98/23700 - S008C002P034R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 99/23700 - S008C001P036R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 100/23700 - S008C001P036R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 101/23700 - S008C003P032R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 102/23700 - S008C001P034R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 103/23700 - S008C003P025R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 104/23700 - S008C002P029R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 105/23700 - S008C001P033R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 106/23700 - S008C003P001R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 107/23700 - S008C003P007R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 108/23700 - S008C001P034R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 109/23700 - S008C003P001R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 110/23700 - S008C003P036R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 111/23700 - S008C002P034R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 112/23700 - S008C001P019R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 113/23700 - S008C002P007R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 114/23700 - S008C003P030R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 115/23700 - S008C002P029R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 116/23700 - S008C001P032R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 117/23700 - S008C001P031R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 118/23700 - S008C001P032R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 119/23700 - S008C001P025R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 120/23700 - S008C003P008R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 121/23700 - S008C001P001R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 122/23700 - S008C002P036R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 123/23700 - S008C003P036R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 124/23700 - S008C002P001R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 125/23700 - S008C003P019R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 126/23700 - S008C001P015R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 127/23700 - S008C002P032R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 128/23700 - S008C003P025R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 129/23700 - S008C003P015R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 130/23700 - S008C003P008R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 131/23700 - S008C002P035R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 132/23700 - S008C001P035R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 133/23700 - S008C002P036R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 134/23700 - S008C003P007R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 135/23700 - S008C002P031R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 136/23700 - S008C002P033R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 137/23700 - S008C001P019R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 138/23700 - S009C003P016R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 139/23700 - S009C001P015R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 140/23700 - S009C002P007R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 141/23700 - S009C003P015R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 142/23700 - S009C003P019R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 143/23700 - S009C001P015R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 144/23700 - S009C002P015R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 145/23700 - S009C002P007R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 146/23700 - S009C002P008R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 147/23700 - S009C001P017R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 148/23700 - S009C001P017R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 149/23700 - S009C002P017R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 150/23700 - S009C002P025R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 151/23700 - S009C002P016R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 152/23700 - S009C003P008R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 153/23700 - S009C003P019R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 154/23700 - S009C003P008R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 155/23700 - S009C001P019R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 156/23700 - S009C002P019R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 157/23700 - S009C002P017R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 158/23700 - S009C002P008R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 159/23700 - S009C003P015R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 160/23700 - S009C003P025R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 161/23700 - S009C003P017R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 162/23700 - S009C002P015R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 163/23700 - S009C001P019R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 164/23700 - S009C001P008R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 165/23700 - S009C002P019R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 166/23700 - S009C001P025R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 167/23700 - S009C001P008R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 168/23700 - S009C003P017R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 169/23700 - S009C001P007R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 170/23700 - S009C001P025R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 171/23700 - S009C003P007R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 172/23700 - S009C002P016R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 173/23700 - S009C002P025R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 174/23700 - S009C001P016R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 175/23700 - S009C003P016R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 176/23700 - S009C003P007R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 177/23700 - S009C001P007R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 178/23700 - S009C001P016R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 179/23700 - S009C003P025R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 180/23700 - S005C002P004R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 181/23700 - S005C001P016R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 182/23700 - S005C002P013R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 183/23700 - S005C003P021R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 184/23700 - S005C002P010R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 185/23700 - S005C002P021R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 186/23700 - S005C003P018R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 187/23700 - S005C001P018R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 188/23700 - S005C002P021R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 189/23700 - S005C002P015R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 190/23700 - S005C001P017R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 191/23700 - S005C003P015R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 192/23700 - S005C001P004R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 193/23700 - S005C002P016R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 194/23700 - S005C001P021R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 195/23700 - S005C001P018R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 196/23700 - S005C003P016R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 197/23700 - S005C003P010R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 198/23700 - S005C003P013R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 199/23700 - S005C003P018R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 200/23700 - S005C002P018R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 201/23700 - S005C002P018R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 202/23700 - S005C001P015R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 203/23700 - S005C002P010R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 204/23700 - S005C003P016R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 205/23700 - S005C003P013R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 206/23700 - S005C003P010R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 207/23700 - S005C002P016R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 208/23700 - S005C003P015R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 209/23700 - S005C002P015R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 210/23700 - S005C001P013R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 211/23700 - S005C001P004R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 212/23700 - S005C003P017R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 213/23700 - S005C001P017R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 214/23700 - S005C001P016R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 215/23700 - S005C003P004R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 216/23700 - S005C001P021R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 217/23700 - S005C001P010R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 218/23700 - S005C002P017R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 219/23700 - S005C001P010R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 220/23700 - S005C001P015R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 221/23700 - S005C003P017R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 222/23700 - S005C001P013R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 223/23700 - S005C002P013R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 224/23700 - S005C003P004R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 225/23700 - S005C002P004R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 226/23700 - S005C003P021R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 227/23700 - S005C002P017R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 228/23700 - S013C001P028R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 229/23700 - S013C003P018R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 230/23700 - S013C002P008R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 231/23700 - S013C001P016R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 232/23700 - S013C001P025R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 233/23700 - S013C001P025R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 234/23700 - S013C002P008R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 235/23700 - S013C002P019R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 236/23700 - S013C001P015R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 237/23700 - S013C003P007R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 238/23700 - S013C001P018R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 239/23700 - S013C002P018R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 240/23700 - S013C003P015R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 241/23700 - S013C002P017R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 242/23700 - S013C002P007R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 243/23700 - S013C002P037R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 244/23700 - S013C003P027R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 245/23700 - S013C002P015R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 246/23700 - S013C001P008R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 247/23700 - S013C001P028R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 248/23700 - S013C002P007R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 249/23700 - S013C002P018R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 250/23700 - S013C001P008R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 251/23700 - S013C003P018R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 252/23700 - S013C003P017R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 253/23700 - S013C001P018R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 254/23700 - S013C001P019R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 255/23700 - S013C003P019R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 256/23700 - S013C002P037R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 257/23700 - S013C001P007R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 258/23700 - S013C003P016R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 259/23700 - S013C002P025R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 260/23700 - S013C002P016R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 261/23700 - S013C003P028R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 262/23700 - S013C003P007R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 263/23700 - S013C002P015R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 264/23700 - S013C003P017R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 265/23700 - S013C002P019R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 266/23700 - S013C002P027R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 267/23700 - S013C003P016R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 268/23700 - S013C001P016R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 269/23700 - S013C001P015R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 270/23700 - S013C002P028R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 271/23700 - S013C003P027R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 272/23700 - S013C001P027R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 273/23700 - S013C001P027R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 274/23700 - S013C001P017R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 275/23700 - S013C002P027R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 276/23700 - S013C001P037R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 277/23700 - S013C001P019R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 278/23700 - S013C003P015R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 279/23700 - S013C002P025R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 280/23700 - S013C003P025R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 281/23700 - S013C002P017R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 282/23700 - S013C002P028R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 283/23700 - S013C003P028R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 284/23700 - S013C003P025R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 285/23700 - S013C003P008R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 286/23700 - S013C003P037R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 287/23700 - S013C001P007R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 288/23700 - S013C002P016R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 289/23700 - S013C001P037R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 290/23700 - S013C001P017R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 291/23700 - S013C003P019R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 292/23700 - S013C003P008R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 293/23700 - S013C003P037R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 294/23700 - S001C002P006R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 295/23700 - S001C002P007R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 296/23700 - S001C003P001R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 297/23700 - S001C002P005R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 298/23700 - S001C001P006R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 299/23700 - S001C001P001R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 300/23700 - S001C003P008R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 301/23700 - S001C002P006R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 302/23700 - S001C002P004R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 303/23700 - S001C002P004R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 304/23700 - S001C001P003R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 305/23700 - S001C002P001R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 306/23700 - S001C002P003R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 307/23700 - S001C002P007R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 308/23700 - S001C003P007R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 309/23700 - S001C001P002R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 310/23700 - S001C003P005R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 311/23700 - S001C002P008R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 312/23700 - S001C003P006R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 313/23700 - S001C001P002R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 314/23700 - S001C002P005R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 315/23700 - S001C003P004R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 316/23700 - S001C001P007R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 317/23700 - S001C001P001R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 318/23700 - S001C002P001R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 319/23700 - S001C001P004R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 320/23700 - S001C002P002R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 321/23700 - S001C003P003R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 322/23700 - S001C001P003R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 323/23700 - S001C002P008R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 324/23700 - S001C001P005R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 325/23700 - S001C003P002R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 326/23700 - S001C003P005R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 327/23700 - S001C002P003R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 328/23700 - S001C003P004R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 329/23700 - S001C003P003R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 330/23700 - S001C001P008R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 331/23700 - S001C003P001R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 332/23700 - S001C001P008R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 333/23700 - S001C001P007R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 334/23700 - S001C002P002R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 335/23700 - S001C001P005R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 336/23700 - S001C003P007R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 337/23700 - S001C003P008R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 338/23700 - S001C001P004R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 339/23700 - S001C003P006R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 340/23700 - S001C001P006R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 341/23700 - S001C003P002R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 342/23700 - S007C003P027R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 343/23700 - S007C003P017R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 344/23700 - S007C001P016R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 345/23700 - S007C001P025R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 346/23700 - S007C003P008R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 347/23700 - S007C003P027R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 348/23700 - S007C003P017R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 349/23700 - S007C001P026R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 350/23700 - S007C001P026R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 351/23700 - S007C002P016R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 352/23700 - S007C002P007R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 353/23700 - S007C003P007R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 354/23700 - S007C003P001R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 355/23700 - S007C003P019R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 356/23700 - S007C002P028R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 357/23700 - S007C001P017R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 358/23700 - S007C001P008R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 359/23700 - S007C002P015R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 360/23700 - S007C002P025R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 361/23700 - S007C001P007R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 362/23700 - S007C002P019R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 363/23700 - S007C003P015R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 364/23700 - S007C003P015R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 365/23700 - S007C001P018R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 366/23700 - S007C001P027R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 367/23700 - S007C001P007R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 368/23700 - S007C001P016R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 369/23700 - S007C003P028R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 370/23700 - S007C003P028R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 371/23700 - S007C001P025R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 372/23700 - S007C001P028R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 373/23700 - S007C003P025R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 374/23700 - S007C003P008R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 375/23700 - S007C002P008R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 376/23700 - S007C002P019R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 377/23700 - S007C003P026R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 378/23700 - S007C002P018R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 379/23700 - S007C002P016R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 380/23700 - S007C001P015R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 381/23700 - S007C003P018R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 382/23700 - S007C002P007R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 383/23700 - S007C003P016R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 384/23700 - S007C003P007R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 385/23700 - S007C003P025R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 386/23700 - S007C002P017R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 387/23700 - S007C003P016R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 388/23700 - S007C002P001R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 389/23700 - S007C001P019R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 390/23700 - S007C002P015R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 391/23700 - S007C001P001R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 392/23700 - S007C002P018R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 393/23700 - S007C001P008R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 394/23700 - S007C002P001R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 395/23700 - S007C001P028R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 396/23700 - S007C002P027R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 397/23700 - S007C002P026R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 398/23700 - S007C001P019R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 399/23700 - S007C002P026R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 400/23700 - S007C002P027R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 401/23700 - S007C001P018R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 402/23700 - S007C001P017R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 403/23700 - S007C002P017R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 404/23700 - S007C001P027R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 405/23700 - S007C003P018R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 406/23700 - S007C001P015R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 407/23700 - S007C003P026R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 408/23700 - S007C003P001R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 409/23700 - S007C002P025R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 410/23700 - S007C002P028R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 411/23700 - S007C001P001R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 412/23700 - S007C003P019R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 413/23700 - S007C002P008R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 414/23700 - S015C001P017R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 415/23700 - S015C003P025R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 416/23700 - S015C002P015R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 417/23700 - S015C001P019R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 418/23700 - S015C001P037R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 419/23700 - S015C003P037R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 420/23700 - S015C002P007R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 421/23700 - S015C003P017R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 422/23700 - S015C002P017R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 423/23700 - S015C003P015R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 424/23700 - S015C002P037R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 425/23700 - S015C001P017R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 426/23700 - S015C002P016R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 427/23700 - S015C003P016R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 428/23700 - S015C002P037R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 429/23700 - S015C003P016R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 430/23700 - S015C002P025R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 431/23700 - S015C002P019R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 432/23700 - S015C001P015R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 433/23700 - S015C003P025R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 434/23700 - S015C002P008R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 435/23700 - S015C003P019R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 436/23700 - S015C001P037R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 437/23700 - S015C002P025R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 438/23700 - S015C003P007R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 439/23700 - S015C001P007R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 440/23700 - S015C001P025R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 441/23700 - S015C003P017R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 442/23700 - S015C002P016R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 443/23700 - S015C001P008R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 444/23700 - S015C003P008R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 445/23700 - S015C001P025R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 446/23700 - S015C002P008R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 447/23700 - S015C001P007R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 448/23700 - S015C003P037R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 449/23700 - S015C001P016R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 450/23700 - S015C003P019R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 451/23700 - S015C002P007R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 452/23700 - S015C003P015R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 453/23700 - S015C001P019R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 454/23700 - S015C001P008R001A004_rgb.avi ############
# #### already completely parsed #####
# ############ 455/23700 - S015C001P016R002A004_rgb.avi ############
# #### already completely parsed #####
# ############ 456/23700 - S015C002P015R001A004_rgb.avi ############
# #### already completely parsed #####
# ...
# #### already completely parsed #####
# ############ 2799/23700 - S014C002P037R001A012_rgb.avi ############
# #### already completely parsed #####
# ############ 2800/23700 - S014C003P025R002A012_rgb.avi ############
# #### already completely parsed #####
# ############ 2801/23700 - S014C001P027R001A012_rgb.avi ############
# #### already completely parsed #####
# ############ 2802/23700 - S014C003P037R002A012_rgb.avi ############
# #### already completely parsed #####
# ############ 2803/23700 - S014C001P008R002A012_rgb.avi ############
# #### already completely parsed #####
# ############ 2804/23700 - S014C002P025R001A012_rgb.avi ############
# #### already completely parsed #####
# ############ 2805/23700 - S014C002P019R002A012_rgb.avi ############
# #### already completely parsed #####
# ############ 2806/23700 - S014C002P037R002A012_rgb.avi ############
# #### already completely parsed #####
# ############ 2807/23700 - S014C002P015R001A012_rgb.avi ############
# #### already completely parsed #####
# ############ 2808/23700 - S014C001P017R001A012_rgb.avi ############
# #### already completely parsed #####
# ############ 2809/23700 - S014C003P037R001A012_rgb.avi ############
# #### already completely parsed #####
# ############ 2810/23700 - S014C002P027R002A012_rgb.avi ############
# #### already completely parsed #####
# ############ 2811/23700 - S014C003P015R001A012_rgb.avi ############
# #### already completely parsed #####
# ############ 2812/23700 - S014C002P015R002A012_rgb.avi ############
# #### already completely parsed #####
# ############ 2813/23700 - S014C002P025R002A012_rgb.avi ############
# #### already completely parsed #####
# ############ 2814/23700 - S014C001P039R001A012_rgb.avi ############
# #### already completely parsed #####
# ############ 2815/23700 - S014C003P019R002A012_rgb.avi ############
# #### already completely parsed #####
# ############ 2816/23700 - S014C001P015R001A012_rgb.avi ############
# #### already completely parsed #####
# ############ 2817/23700 - S014C003P039R001A012_rgb.avi ############
# #### already completely parsed #####
# ############ 2818/23700 - S014C001P007R001A012_rgb.avi ############
# #### already completely parsed #####
# ############ 2819/23700 - S014C001P008R001A012_rgb.avi ############
# #### already completely parsed #####
# ############ 2820/23700 - S014C003P039R002A012_rgb.avi ############
# #### already completely parsed #####
# ############ 2821/23700 - S014C003P007R001A012_rgb.avi ############
# #### already completely parsed #####
# ############ 2822/23700 - S014C003P017R001A012_rgb.avi ############
# #### already completely parsed #####
# ############ 2823/23700 - S014C002P007R001A012_rgb.avi ############
# #### already completely parsed #####
# ############ 2824/23700 - S014C001P015R002A012_rgb.avi ############
# #### already completely parsed #####
# ############ 2825/23700 - S014C001P037R002A012_rgb.avi ############
# #### already completely parsed #####
# ############ 2826/23700 - S014C001P039R002A012_rgb.avi ############
# #### already completely parsed #####
# ############ 2827/23700 - S014C001P019R001A012_rgb.avi ############
# #### already completely parsed #####
# ############ 2828/23700 - S014C003P025R001A012_rgb.avi ############
# #### already completely parsed #####
# ############ 2829/23700 - S014C001P025R001A012_rgb.avi ############
# #### already completely parsed #####
# ############ 2830/23700 - S014C001P027R002A012_rgb.avi ############
# #### already completely parsed #####
# ############ 2831/23700 - S014C001P025R002A012_rgb.avi ############
# #### already completely parsed #####
# ############ 2832/23700 - S014C001P017R002A012_rgb.avi ############
# #### already completely parsed #####
# ############ 2833/23700 - S014C002P039R001A012_rgb.avi ############
# #### already completely parsed #####
# ############ 2834/23700 - S014C003P015R002A012_rgb.avi ############
# #### already completely parsed #####
# ############ 2835/23700 - S014C003P027R001A012_rgb.avi ############
# #### already completely parsed #####
# ############ 2836/23700 - S014C002P007R002A012_rgb.avi ############
# #### already completely parsed #####
# ############ 2837/23700 - S014C002P019R001A012_rgb.avi ############
# #### already completely parsed #####
# ############ 2838/23700 - S014C003P017R002A012_rgb.avi ############
# #### already completely parsed #####
# ############ 2839/23700 - S014C003P019R001A012_rgb.avi ############
# #### already completely parsed #####
# ############ 2840/23700 - S014C001P037R001A012_rgb.avi ############
# #### already completely parsed #####
# ############ 2841/23700 - S014C002P017R002A012_rgb.avi ############
# #### already completely parsed #####
# ############ 2842/23700 - S014C002P008R001A012_rgb.avi ############
# #### already completely parsed #####
# ############ 2843/23700 - S014C002P008R002A012_rgb.avi ############
# #### already completely parsed #####
# ############ 2844/23700 - S003C001P017R001A014_rgb.avi ############
# removing incorrect folder /data/students_home/amoscatelli/Desktop/actionAnalysis/inputData/S003C001P017R001A014_rgb/Detectron2-keypoint_rcnn_X_101_32x8d_FPN_3x
# Original FPS: 30
# Requested FPS: 30
# length: 151 width: 1920 height: 1080
# pick 1 frame every 1
# ######  video already parsed with PosenNet #####
# ######  PoseNet done  #####
# ######  parsing with Detectron2.... #####
# ######  Detectron2 done! #####
# ############ 2845/23700 - S003C001P015R002A014_rgb.avi ############
# /data/students_home/amoscatelli/Desktop/actionAnalysis/inputData/S003C001P015R002A014_rgb doesn't contain ['Detectron2-keypoint_rcnn_X_101_32x8d_FPN_3x', 'PoseNet-101']
# Original FPS: 30
# Requested FPS: 30
# length: 156 width: 1920 height: 1080
# pick 1 frame every 1
# /data/students_home/amoscatelli/Desktop/actionAnalysis/miniconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /data/students_home/amoscatelli/Desktop/actionAnalysis/miniconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /data/students_home/amoscatelli/Desktop/actionAnalysis/miniconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /data/students_home/amoscatelli/Desktop/actionAnalysis/miniconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /data/students_home/amoscatelli/Desktop/actionAnalysis/miniconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /data/students_home/amoscatelli/Desktop/actionAnalysis/miniconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /data/students_home/amoscatelli/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /data/students_home/amoscatelli/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /data/students_home/amoscatelli/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /data/students_home/amoscatelli/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /data/students_home/amoscatelli/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /data/students_home/amoscatelli/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# WARNING:tensorflow:From keyPointsLogger.py:23: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# /data/students_home/amoscatelli/Desktop/actionAnalysis/posenet-python/posenet/converter/config.py:9: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   cfg = yaml.load(cfg_f)
# WARNING:tensorflow:From /data/students_home/amoscatelli/Desktop/actionAnalysis/posenet-python/posenet/model.py:45: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# WARNING:tensorflow:From /data/students_home/amoscatelli/Desktop/actionAnalysis/posenet-python/posenet/model.py:46: The name tf.GraphDef is deprecated. Please use tf.compat.v1.GraphDef instead.
#
# Average FPS: 7.056029666770663
# ######  PoseNet done  #####
# ######  parsing with Detectron2.... #####
# ######  Detectron2 done! #####
# ############ 2846/23700 - S003C001P008R001A014_rgb.avi ############
# /data/students_home/amoscatelli/Desktop/actionAnalysis/inputData/S003C001P008R001A014_rgb doesn't contain ['Detectron2-keypoint_rcnn_X_101_32x8d_FPN_3x', 'PoseNet-101']
# Original FPS: 30
# Requested FPS: 30
# length: 210 width: 1920 height: 1080
# pick 1 frame every 1
# /data/students_home/amoscatelli/Desktop/actionAnalysis/miniconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /data/students_home/amoscatelli/Desktop/actionAnalysis/miniconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /data/students_home/amoscatelli/Desktop/actionAnalysis/miniconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /data/students_home/amoscatelli/Desktop/actionAnalysis/miniconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /data/students_home/amoscatelli/Desktop/actionAnalysis/miniconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /data/students_home/amoscatelli/Desktop/actionAnalysis/miniconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /data/students_home/amoscatelli/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /data/students_home/amoscatelli/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /data/students_home/amoscatelli/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /data/students_home/amoscatelli/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /data/students_home/amoscatelli/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /data/students_home/amoscatelli/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# WARNING:tensorflow:From keyPointsLogger.py:23: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# /data/students_home/amoscatelli/Desktop/actionAnalysis/posenet-python/posenet/converter/config.py:9: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   cfg = yaml.load(cfg_f)
# WARNING:tensorflow:From /data/students_home/amoscatelli/Desktop/actionAnalysis/posenet-python/posenet/model.py:45: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# WARNING:tensorflow:From /data/students_home/amoscatelli/Desktop/actionAnalysis/posenet-python/posenet/model.py:46: The name tf.GraphDef is deprecated. Please use tf.compat.v1.GraphDef instead.
#
# Average FPS: 7.350620507586007
# ######  PoseNet done  #####
# ######  parsing with Detectron2.... #####

# %%
# %%javascript
# Jupyter.notebook.session.delete();

# %%
datetime.fromtimestamp(-60*60).strftime("%H:%M:%S")
# Out:
# '00:00:00'

# %% [markdown]
# # See what's saved

# %% [markdown]
# ## DensePose (switch to python 2)

# %%
# !ls -la /data/students_home/amoscatelli/Desktop/actionAnalysis/inputData/S002C002P010R001A009_rgb/DensePoseKeyPointsMask_ResNet50_FPN_s1x-e2e/
# Out:
# total 262912
# drwxrwxr-x 2 amoscatelli amoscatelli    4096 gen  3 13:59 .
# drwxrwxr-x 5 amoscatelli amoscatelli    4096 gen  3 13:58 ..
# -rw-rw-r-- 1 amoscatelli amoscatelli 1665201 gen  3 13:59 frame0000.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 1636828 gen  3 13:59 frame0001.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 1646080 gen  3 13:58 frame0002.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 1623791 gen  3 13:58 frame0003.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 1641883 gen  3 13:59 frame0004.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 1636711 gen  3 13:59 frame0005.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 1644991 gen  3 13:59 frame0006.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 1711367 gen  3 13:58 frame0007.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 1649907 gen  3 13:59 frame0008.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 1649857 gen  3 13:58 frame0009.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 1646566 gen  3 13:58 frame0010.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 1635776 gen  3 13:58 frame0011.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 1610316 gen  3 13:58 frame0012.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 1662839 gen  3 13:58 frame0013.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 1753195 gen  3 13:58 frame0014.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 1712811 gen  3 13:59 frame0015.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 1657714 gen  3 13:59 frame0016.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 1657738 gen  3 13:59 frame0017.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 2561039 gen  3 13:59 frame0018.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 1625578 gen  3 13:59 frame0019.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 2440743 gen  3 13:58 frame0020.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 1567219 gen  3 13:59 frame0021.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 1639155 gen  3 13:59 frame0022.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 2564352 gen  3 13:59 frame0023.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 2535642 gen  3 13:59 frame0024.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 2350870 gen  3 13:59 frame0025.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 2220426 gen  3 13:58 frame0026.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 2208857 gen  3 13:58 frame0027.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 1648168 gen  3 13:58 frame0028.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 1717687 gen  3 13:59 frame0029.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 2469272 gen  3 13:59 frame0030.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 1645883 gen  3 13:58 frame0031.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 1638318 gen  3 13:59 frame0032.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 1642144 gen  3 13:58 frame0033.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 1679240 gen  3 13:59 frame0034.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 1665727 gen  3 13:58 frame0035.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 1652783 gen  3 13:58 frame0036.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 2252402 gen  3 13:58 frame0037.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 1622960 gen  3 13:58 frame0038.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 2157172 gen  3 13:59 frame0039.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 1651282 gen  3 13:58 frame0040.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 1716815 gen  3 13:58 frame0041.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 1720442 gen  3 13:58 frame0042.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 2830992 gen  3 13:58 frame0043.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 2829429 gen  3 13:58 frame0044.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 3560889 gen  3 13:59 frame0045.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 1887248 gen  3 13:58 frame0046.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 1932158 gen  3 13:59 frame0047.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 2082846 gen  3 13:58 frame0048.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 2259785 gen  3 13:59 frame0049.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 2382481 gen  3 13:58 frame0050.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 2955160 gen  3 13:58 frame0051.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 2568807 gen  3 13:59 frame0052.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 1526334 gen  3 13:58 frame0053.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 1561938 gen  3 13:59 frame0054.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 1693977 gen  3 13:58 frame0055.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 1645992 gen  3 13:59 frame0056.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 1731597 gen  3 13:58 frame0057.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 1693704 gen  3 13:58 frame0058.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 2628102 gen  3 13:59 frame0059.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 1625932 gen  3 13:59 frame0060.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 2191531 gen  3 13:58 frame0061.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 1658150 gen  3 13:59 frame0062.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 1583566 gen  3 13:59 frame0063.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 1627026 gen  3 13:59 frame0064.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 2128448 gen  3 13:59 frame0065.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 2384646 gen  3 13:58 frame0066.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 2606530 gen  3 13:58 frame0067.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 2453602 gen  3 13:59 frame0068.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 2400766 gen  3 13:58 frame0069.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 1680039 gen  3 13:59 frame0070.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 1677221 gen  3 13:59 frame0071.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 2157412 gen  3 13:59 frame0072.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 2691556 gen  3 13:58 frame0073.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 2681405 gen  3 13:58 frame0074.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 2294245 gen  3 13:59 frame0075.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 2603918 gen  3 13:59 frame0076.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 2708611 gen  3 13:59 frame0077.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 2675014 gen  3 13:59 frame0078.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 2613405 gen  3 13:59 frame0079.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 2593547 gen  3 13:59 frame0080.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 2650183 gen  3 13:59 frame0081.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 1895100 gen  3 13:58 frame0082.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 2727944 gen  3 13:59 frame0083.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 2784402 gen  3 13:58 frame0084.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 2426434 gen  3 13:59 frame0085.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 2404512 gen  3 13:59 frame0086.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 2650064 gen  3 13:59 frame0087.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 2128081 gen  3 13:59 frame0088.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 2125263 gen  3 13:59 frame0089.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 2389734 gen  3 13:59 frame0090.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 2390796 gen  3 13:59 frame0091.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 2076109 gen  3 13:58 frame0092.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 2734438 gen  3 13:58 frame0093.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 3023533 gen  3 13:58 frame0094.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 2637020 gen  3 13:58 frame0095.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 3176096 gen  3 13:58 frame0096.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 2853490 gen  3 13:58 frame0097.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 2018172 gen  3 13:59 frame0098.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 2259415 gen  3 13:59 frame0099.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 2580595 gen  3 13:59 frame0100.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 2428887 gen  3 13:59 frame0101.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 2265327 gen  3 13:58 frame0102.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 2558997 gen  3 13:59 frame0103.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 1767129 gen  3 13:59 frame0104.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 2517085 gen  3 13:58 frame0105.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 1738334 gen  3 13:58 frame0106.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 2347441 gen  3 13:58 frame0107.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 1631997 gen  3 13:59 frame0108.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 2392650 gen  3 13:59 frame0109.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 2444827 gen  3 13:59 frame0110.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 2450754 gen  3 13:58 frame0111.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 2542512 gen  3 13:59 frame0112.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 1709060 gen  3 13:58 frame0113.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 2592208 gen  3 13:59 frame0114.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 2666882 gen  3 13:59 frame0115.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 1694963 gen  3 13:58 frame0116.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 2631385 gen  3 13:59 frame0117.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 2631002 gen  3 13:59 frame0118.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 1589386 gen  3 13:59 frame0119.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 2640468 gen  3 13:58 frame0120.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 1729539 gen  3 13:59 frame0121.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 1677195 gen  3 13:58 frame0122.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 1651616 gen  3 13:59 frame0123.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 1673104 gen  3 13:58 frame0124.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 1675532 gen  3 13:59 frame0125.pickle
# -rw-rw-r-- 1 amoscatelli amoscatelli 1645124 gen  3 13:59 frame0126.pickle

# %%
extractFrames("S002C002P010R001A009_rgb.avi")
# Out:
# Original FPS: 30
# Requested FPS: 30
# length: 63 width: 1920 height: 1080
# pick 1 frame every 1
# rm: cannot remove './temp/*': No such file or directory

# %%
import pickle
with open("/data/students_home/amoscatelli/Desktop/actionAnalysis/inputData/S010C003P007R001A001_rgb/DensePose_ResNet101_FPN_32x8d_s1x-e2e/frame0001.pickle",'rb') as file_in:
    cls_boxes, cls_segms, cls_keyps, cls_bodys = pickle.load(file_in)

# %%
import numpy as np
def convert_from_cls_format(cls_boxes, cls_segms, cls_keyps):
    """Convert from the class boxes/segms/keyps format generated by the testing
    code.
    """
    box_list = [b for b in cls_boxes if len(b) > 0]
    if len(box_list) > 0:
        boxes = np.concatenate(box_list)
    else:
        boxes = None
    if cls_segms is not None:
        segms = [s for slist in cls_segms for s in slist]
    else:
        segms = None
    if cls_keyps is not None:
        keyps = [k for klist in cls_keyps for k in klist]
    else:
        keyps = None
    classes = []
    for j in range(len(cls_boxes)):
        classes += [j] * len(cls_boxes[j])
    return boxes, segms, keyps, classes

# %%
boxes, segms, keyps, classes = convert_from_cls_format(cls_boxes, cls_segms, cls_keyps)

# %%
boxes
# Out:
# array([[8.3277179e+02, 2.5318958e+02, 1.0303516e+03, 8.0129248e+02,
#         9.9988616e-01]], dtype=float32)

# %%
def vis_bbox(img, bbox, thick=1):
    """Visualizes a bounding box."""
    (x0, y0, w, h) = bbox
    x1, y1 = int(x0 + w), int(y0 + h)
    x0, y0 = int(x0), int(y0)
    cv2.rectangle(img, (x0, y0), (x1, y1), _GREEN, thickness=thick)
    return img

# %%
import cv2
im_name = "temp/frame0001.jpg"
im = cv2.imread(im_name)
im = im[:, :, ::-1]
print(im.shape[0],im.shape[1]) # (1080, 1920)

#   DensePose Visualization Starts!!
##  Get full IUV image out 
IUV_fields = cls_bodys[1]
#
All_Coords = np.zeros(im.shape)
All_inds = np.zeros([im.shape[0],im.shape[1]])
K = 26
##
inds = np.argsort(boxes[:,4])
##
for i, ind in enumerate(inds):
    entry = boxes[ind,:]
    if entry[4] > 0.65:
        entry=entry[0:4].astype(int)
        ####
        output = IUV_fields[ind]
        ####
        All_Coords_Old = All_Coords[ entry[1] : entry[1]+output.shape[1],entry[0]:entry[0]+output.shape[2],:]
        All_Coords_Old[All_Coords_Old==0]=output.transpose([1,2,0])[All_Coords_Old==0]
        All_Coords[ entry[1] : entry[1]+output.shape[1],entry[0]:entry[0]+output.shape[2],:]= All_Coords_Old
        ###
        CurrentMask = (output[0,:,:]>0).astype(np.float32)
        All_inds_old = All_inds[ entry[1] : entry[1]+output.shape[1],entry[0]:entry[0]+output.shape[2]]
        All_inds_old[All_inds_old==0] = CurrentMask[All_inds_old==0]*i
        All_inds[ entry[1] : entry[1]+output.shape[1],entry[0]:entry[0]+output.shape[2]] = All_inds_old
#
All_Coords[:,:,1:3] = 255. * All_Coords[:,:,1:3]
All_Coords[All_Coords>255] = 255.
All_Coords = All_Coords.astype(np.uint8)
All_inds = All_inds.astype(np.uint8)
# Out:
# (1080, 1920)

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=[20, 20])
plt.imshow( im[:,:,::-1] )
plt.contour( All_Coords[:,:,1]/256.,10, linewidths = 1 )
plt.contour( All_Coords[:,:,2]/256.,10, linewidths = 1 )
plt.axis('off') ; plt.show()

# %%
IUV_fields = cls_bodys[1]
IUV_fields[0].shape[2]
# Out:
# 197

# %%
import matplotlib.pyplot as plt
plt.contour( cls_boxes[:,:,2]/256.,10, linewidths = 1 )
plt.axis('off') ; plt.show()
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-29-e36f9358bf2b> in <module>()
#       1 import matplotlib.pyplot as plt
# ----> 2 plt.contour( cls_boxes[:,:,2]/256.,10, linewidths = 1 )
#       3 plt.axis('off') ; plt.show()
#
# TypeError: list indices must be integers, not tuple

# %%
import sys
if '/data/students_home/amoscatelli/Desktop/actionAnalysis/DensePose/' not in sys.path: 
    sys.path.insert(1, '/data/students_home/amoscatelli/Desktop/actionAnalysis/DensePose/')
# import pickle
import detectron.utils.vis as vis_utils
import detectron.datasets.dummy_datasets as dummy_datasets

DENSEPOSE_OUTPUT_DIR = "tempPictures/"
im_name = "temp/frame0061.jpg"

dummy_coco_dataset = dummy_datasets.get_coco_dataset()
im = cv2.imread(im_name)
vis_utils.vis_one_image(
            im[:, :, ::-1],  # BGR -> RGB for visualization
            im_name,
            DENSEPOSE_OUTPUT_DIR,
            cls_boxes,
            cls_segms,
            cls_keyps,
            cls_bodys,
            dataset=dummy_coco_dataset,
            box_alpha=0.3,
            show_class=True,
            thresh=0.7,
            kp_thresh=2
        )
# Out:
# ImportErrorTraceback (most recent call last)
# <ipython-input-2-413c4544b6fd> in <module>()
#       3     sys.path.insert(1, '/data/students_home/amoscatelli/Desktop/actionAnalysis/DensePose/')
#       4 # import pickle
# ----> 5 import detectron.utils.vis as vis_utils
#       6 import detectron.datasets.dummy_datasets as dummy_datasets
#       7
#
# /data/students_home/amoscatelli/Desktop/actionAnalysis/DensePose/detectron/utils/vis.py in <module>()
#      17 import os
#      18
# ---> 19 import pycocotools.mask as mask_util
#      20
#      21 from detectron.utils.colormap import colormap
#
# ImportError: No module named pycocotools.mask

# %%
if '/data/students_home/amoscatelli/Desktop/actionAnalysis/DensePose/' not in sys.path: 
    sys.path.insert(1, '/data/students_home/amoscatelli/Desktop/actionAnalysis/DensePose/')
sys.path
# Out:
# ['',
#  '/data/students_home/amoscatelli/Desktop/actionAnalysis/DensePose/',
#  '/usr/lib/python36.zip',
#  '/usr/lib/python3.6',
#  '/usr/lib/python3.6/lib-dynload',
#  '/data/students_home/amoscatelli/.local/lib/python3.6/site-packages',
#  '/data/students_home/amoscatelli/Desktop/actionAnalysis/detectron2_repo',
#  '/usr/local/lib/python3.6/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/lib/python3/dist-packages/IPython/extensions',
#  '/data/students_home/amoscatelli/.ipython']

# %%
# !ls temp/
# Out:
# frame0000.jpg  frame0028.jpg  frame0056.jpg  frame0084.jpg  frame0112.jpg
# frame0001.jpg  frame0029.jpg  frame0057.jpg  frame0085.jpg  frame0113.jpg
# frame0002.jpg  frame0030.jpg  frame0058.jpg  frame0086.jpg  frame0114.jpg
# frame0003.jpg  frame0031.jpg  frame0059.jpg  frame0087.jpg  frame0115.jpg
# frame0004.jpg  frame0032.jpg  frame0060.jpg  frame0088.jpg  frame0116.jpg
# frame0005.jpg  frame0033.jpg  frame0061.jpg  frame0089.jpg  frame0117.jpg
# frame0006.jpg  frame0034.jpg  frame0062.jpg  frame0090.jpg  frame0118.jpg
# frame0007.jpg  frame0035.jpg  frame0063.jpg  frame0091.jpg  frame0119.jpg
# frame0008.jpg  frame0036.jpg  frame0064.jpg  frame0092.jpg  frame0120.jpg
# frame0009.jpg  frame0037.jpg  frame0065.jpg  frame0093.jpg  frame0121.jpg
# frame0010.jpg  frame0038.jpg  frame0066.jpg  frame0094.jpg  frame0122.jpg
# frame0011.jpg  frame0039.jpg  frame0067.jpg  frame0095.jpg  frame0123.jpg
# frame0012.jpg  frame0040.jpg  frame0068.jpg  frame0096.jpg  frame0124.jpg
# frame0013.jpg  frame0041.jpg  frame0069.jpg  frame0097.jpg  frame0125.jpg
# frame0014.jpg  frame0042.jpg  frame0070.jpg  frame0098.jpg  frame0126.jpg
# frame0015.jpg  frame0043.jpg  frame0071.jpg  frame0099.jpg  frame0127.jpg
# frame0016.jpg  frame0044.jpg  frame0072.jpg  frame0100.jpg  frame0128.jpg
# frame0017.jpg  frame0045.jpg  frame0073.jpg  frame0101.jpg  frame0129.jpg
# frame0018.jpg  frame0046.jpg  frame0074.jpg  frame0102.jpg  frame0130.jpg
# frame0019.jpg  frame0047.jpg  frame0075.jpg  frame0103.jpg  frame0131.jpg
# frame0020.jpg  frame0048.jpg  frame0076.jpg  frame0104.jpg  frame0132.jpg
# frame0021.jpg  frame0049.jpg  frame0077.jpg  frame0105.jpg  frame0133.jpg
# frame0022.jpg  frame0050.jpg  frame0078.jpg  frame0106.jpg  frame0134.jpg
# frame0023.jpg  frame0051.jpg  frame0079.jpg  frame0107.jpg  frame0135.jpg
# frame0024.jpg  frame0052.jpg  frame0080.jpg  frame0108.jpg
# frame0025.jpg  frame0053.jpg  frame0081.jpg  frame0109.jpg
# frame0026.jpg  frame0054.jpg  frame0082.jpg  frame0110.jpg
# frame0027.jpg  frame0055.jpg  frame0083.jpg  frame0111.jpg

# %%
# !pip3 install future
# Out:
# Collecting future
#   Downloading https://files.pythonhosted.org/packages/45/0b/38b06fd9b92dc2b68d58b75f900e97884c45bedd2ff83203d933cf5851c9/future-0.18.2.tar.gz (829kB)
#     100% |████████████████████████████████| 829kB 1.2MB/s ta 0:00:01
# Building wheels for collected packages: future
#   Running setup.py bdist_wheel for future ... done
#   Stored in directory: /data/students_home/amoscatelli/.cache/pip/wheels/8b/99/a0/81daf51dcd359a9377b110a8a886b3895921802d2fc1b2397e
# Successfully built future
# Installing collected packages: future
# Successfully installed future-0.18.2

# %% [markdown]
# ## Area test

# %%
# !pip install cPickle
# Out:
# DEPRECATION: Python 2.7 will reach the end of its life on January 1st, 2020. Please upgrade your Python as Python 2.7 won't be maintained after that date. A future version of pip will drop support for Python 2.7.
# Collecting cPickle
#   ERROR: Could not find a version that satisfies the requirement cPickle (from versions: none)
# ERROR: No matching distribution found for cPickle
# WARNING: You are using pip version 19.1.1, however version 19.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# !export CUDA_VISIBLE_DEVICES=0,1,2 && python3 -c "import torch;print(torch.cuda.get_device_name(0));print(torch.cuda.get_device_name(1));print(torch.cuda.get_device_name(2))"
# !export CUDA_VISIBLE_DEVICES=0,1,2 && python3 -c "import torch;print(torch.cuda.get_device_capability(2))"
# torch.cuda.memory_allocated(0), torch.cuda.get_device_name(0)
# torch.cuda.device_count()
torch.cuda.get_device_name(0)
# torch.cuda.memory_cached(0)
# ,torch.cuda.get_device_name(1),torch.cuda.get_device_name(2)
# Out:
# 'GeForce GTX TITAN X'

# %%
os.environ['CUDA_VISIBLE_DEVICES'] = "1,2"
# # !export CUDA_VISIBLE_DEVICES = "0,1,2"
for i in range(torch.cuda.device_count()):
    print(torch.cuda.get_device_name(i))

# !export CUDA_VISIBLE_DEVICES="0,1" && 
# !export CUDA_VISIBLE_DEVICES="0,1,2" && python2 -c "import torch; print(torch.cuda.device_count())"
# Out:
# GeForce GTX TITAN X
# Quadro K600

# %%
# !cd $PROJECT_FOLDER/DensePose && ls configs/$densePoseConfigName.yaml
# !cd $PROJECT_FOLDER/DensePose && ls configs/$densePoseConfigName
# Out:
# configs/DensePose_ResNet101_FPN_32x8d_s1x-e2e.yaml

# %%
densePoseConfigName
# Out:
# 'DensePose_ResNet101_FPN_32x8d_s1x-e2e'

# %%
# !cd $PROJECT_FOLDER/posenet-python && python keyPointsLogger.py \
# --model $poseNetModel \
# --image_dir ../src/temp \
# --output_dir $poseNetFolder \
# Out:
# Traceback (most recent call last):
#   File "keyPointsLogger.py", line 7, in <module>
#     import posenet
#   File "/data/students_home/amoscatelli/Desktop/actionAnalysis/posenet-python/posenet/__init__.py", line 3, in <module>
#     from posenet.model import load_model
#   File "/data/students_home/amoscatelli/Desktop/actionAnalysis/posenet-python/posenet/model.py", line 3, in <module>
#     import posenet.converter.config
# ImportError: No module named converter.config

# %%
type(sys.path)
# Out:
# list

# %%
# !ls ../inputData/S010C003P007R001A001_rgb/DensePose_ResNet101_FPN_32x8d_s1x-e2e/
# Out:
# frame0000.pickle  frame0034.pickle  frame0068.pickle  frame0102.pickle
# frame0001.pickle  frame0035.pickle  frame0069.pickle  frame0103.pickle
# frame0002.pickle  frame0036.pickle  frame0070.pickle  frame0104.pickle
# frame0003.pickle  frame0037.pickle  frame0071.pickle  frame0105.pickle
# frame0004.pickle  frame0038.pickle  frame0072.pickle  frame0106.pickle
# frame0005.pickle  frame0039.pickle  frame0073.pickle  frame0107.pickle
# frame0006.pickle  frame0040.pickle  frame0074.pickle  frame0108.pickle
# frame0007.pickle  frame0041.pickle  frame0075.pickle  frame0109.pickle
# frame0008.pickle  frame0042.pickle  frame0076.pickle  frame0110.pickle
# frame0009.pickle  frame0043.pickle  frame0077.pickle  frame0111.pickle
# frame0010.pickle  frame0044.pickle  frame0078.pickle  frame0112.pickle
# frame0011.pickle  frame0045.pickle  frame0079.pickle  frame0113.pickle
# frame0012.pickle  frame0046.pickle  frame0080.pickle  frame0114.pickle
# frame0013.pickle  frame0047.pickle  frame0081.pickle  frame0115.pickle
# frame0014.pickle  frame0048.pickle  frame0082.pickle  frame0116.pickle
# frame0015.pickle  frame0049.pickle  frame0083.pickle  frame0117.pickle
# frame0016.pickle  frame0050.pickle  frame0084.pickle  frame0118.pickle
# frame0017.pickle  frame0051.pickle  frame0085.pickle  frame0119.pickle
# frame0018.pickle  frame0052.pickle  frame0086.pickle  frame0120.pickle
# frame0019.pickle  frame0053.pickle  frame0087.pickle  frame0121.pickle
# frame0020.pickle  frame0054.pickle  frame0088.pickle  frame0122.pickle
# frame0021.pickle  frame0055.pickle  frame0089.pickle  frame0123.pickle
# frame0022.pickle  frame0056.pickle  frame0090.pickle  frame0124.pickle
# frame0023.pickle  frame0057.pickle  frame0091.pickle  frame0125.pickle
# frame0024.pickle  frame0058.pickle  frame0092.pickle  frame0126.pickle
# frame0025.pickle  frame0059.pickle  frame0093.pickle  frame0127.pickle
# frame0026.pickle  frame0060.pickle  frame0094.pickle  frame0128.pickle
# frame0027.pickle  frame0061.pickle  frame0095.pickle  frame0129.pickle
# frame0028.pickle  frame0062.pickle  frame0096.pickle  frame0130.pickle
# frame0029.pickle  frame0063.pickle  frame0097.pickle  frame0131.pickle
# frame0030.pickle  frame0064.pickle  frame0098.pickle  frame0132.pickle
# frame0031.pickle  frame0065.pickle  frame0099.pickle  frame0133.pickle
# frame0032.pickle  frame0066.pickle  frame0100.pickle  frame0134.pickle
# frame0033.pickle  frame0067.pickle  frame0101.pickle  frame0135.pickle

# %%
# with open('filename.pickle', 'wb') as handle:
#     pickle.dump(a, handle, protocol=pickle.HIGHEST_PROTOCOL)

# with open('filename.pickle', 'rb') as handle:
#     b = pickle.load(handle)

# %%
import subprocess, re, os, sys

# GPU picking
# http://stackoverflow.com/a/41638727/419116
# Nvidia-smi GPU memory parsing.
# Tested on nvidia-smi 370.23

def run_command(cmd):
    """Run command, return output as string."""
    
    output = subprocess.Popen(cmd, stdout=subprocess.PIPE, shell=True).communicate()[0]
    return output.decode("ascii")

def list_available_gpus():
    """Returns list of available GPU ids."""
    
    output = run_command("nvidia-smi -L")
    # lines of the form GPU 0: TITAN X
    gpu_regex = re.compile(r"GPU (?P<gpu_id>\d+):")
    result = []
    for line in output.strip().split("\n"):
        m = gpu_regex.match(line)
        assert m, "Couldnt parse "+line
        result.append(int(m.group("gpu_id")))
    return result

def gpu_memory_map():
    """Returns map of GPU id to memory allocated on that GPU."""

    output = run_command("nvidia-smi")
    gpu_output = output[output.find("GPU Memory"):]
    # lines of the form
    # |    0      8734    C   python                                       11705MiB |
    memory_regex = re.compile(r"[|]\s+?(?P<gpu_id>\d+)\D+?(?P<pid>\d+).+[ ](?P<gpu_memory>\d+)MiB")
    rows = gpu_output.split("\n")
    result = {gpu_id: 0 for gpu_id in list_available_gpus()}
    for row in gpu_output.split("\n"):
        m = memory_regex.search(row)
        if not m:
            continue
        gpu_id = int(m.group("gpu_id"))
        gpu_memory = int(m.group("gpu_memory"))
        result[gpu_id] += gpu_memory
    return result

def pick_gpu_lowest_memory():
    """Returns GPU with the least allocated memory"""

    memory_gpu_map = [(memory, gpu_id) for (gpu_id, memory) in gpu_memory_map().items()]
    best_memory, best_gpu = sorted(memory_gpu_map)[0]
    return best_gpu

def setup_one_gpu():
    assert not 'tensorflow' in sys.modules, "GPU setup must happen before importing TensorFlow"
    gpu_id = pick_gpu_lowest_memory()
    print("Picking GPU "+str(gpu_id))
    os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
    os.environ["CUDA_VISIBLE_DEVICES"] = str(gpu_id)

def setup_no_gpu():
    if 'tensorflow' in sys.modules:
        print("Warning, GPU setup must happen before importing TensorFlow")
    os.environ["CUDA_VISIBLE_DEVICES"] = ''

# %%
# import os
list_available_gpus()
# Out:
# [0, 1, 2]

# %% [markdown]
# ## Display points

# %% [markdown]
# ### Detectron2

# %%
#Detectron2
videoName = "S003C002P015R001A007_rgb.avi"
detectronConfigName = "/detectron2_repo/configs/COCO-Keypoints/keypoint_rcnn_X_101_32x8d_FPN_3x.yaml"

import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(num=None, figsize=(10, 6), dpi=80, facecolor='w', edgecolor='k')

#extractFrames(videoName) # extract the video frames in ./temp
framePaths = [f.path for f in os.scandir("./temp") if f.is_file() and f.path.endswith('.jpg')]
video_points_folder_name = PROJECT_FOLDER+"/inputData/"+videoName[:-4] #removing the .avi extension

detectron2Model = detectronConfigName.split("/")[-1][:-5]
detectron2Folder = video_points_folder_name+"/Detectron2-"+str(detectron2Model)

frame_path = framePaths[1]
print(frame_path)
im = cv2.imread(frame_path)
outputsFile = frame_path.split("/")[-1][:-4]+".pickle"
with open(join(detectron2Folder,outputsFile), 'rb') as file_in:
    outputs = pickle.load(file_in)        
v = Visualizer(im[:,:,::-1], MetadataCatalog.get(cfg.DATASETS.TRAIN[0]), scale=1.2)
v = v.draw_instance_predictions(outputs["instances"].to("cpu"))
plt.imshow(v.get_image()[:, :, ::1])
# Out:
# ./temp/frame0010.jpg

# %% [markdown]
# ### PoseNet

# %%
# PoseNet
videoName = "S003C002P015R001A007_rgb.avi"
poseNetModel = 101 #50, 75, 100, 101

from IPython.display import Image
import tensorflow as tf
import sys
from sys import path
if "../posenet-python/" not in sys.path:
    sys.path.insert(1, '../posenet-python/')
import posenet
figure(num=None, figsize=(10, 6), dpi=80, facecolor='w', edgecolor='k')


#extractFrames(videoName) # extract the video frames in ./temp
framePaths = [f.path for f in os.scandir("./temp") if f.is_file() and f.path.endswith('.jpg')]
video_points_folder_name = PROJECT_FOLDER+"/inputData/"+videoName[:-4] #removing the .avi extension
poseNetFolder = video_points_folder_name+"/PoseNet-"+str(poseNetModel)
frame_path = framePaths[1]
print("Video: {} PoseNet model: {} frame_path: {}".format(videoName, poseNetModel, frame_path))

with tf.Session() as sess:
    model_cfg, model_outputs = posenet.load_model(poseNetModel, sess)
    output_stride = model_cfg['output_stride']
        

    input_image, draw_image, output_scale = posenet.read_imgfile(
                    frame_path, scale_factor=1.0, output_stride=output_stride)

    frame_points_file_name = frame_path.split("/")[-1][:-4]+".pickle"
    with open(join(poseNetFolder,outputsFile), 'rb') as handle:
        pose_scores, keypoint_scores, keypoint_coords = pickle.load(handle)

    draw_image = posenet.draw_skel_and_kp(
        draw_image, pose_scores, keypoint_scores, keypoint_coords,
#         min_pose_score=0.25, min_part_score=0.25)
        min_pose_score=0., min_part_score=0.)

    plt.imshow(draw_image[:, :, ::-1])
#     cv2.imwrite(os.path.join(args.output_dir, os.path.relpath(f, args.image_dir)), draw_image)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /usr/lib/python3/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Video: S003C002P015R001A007_rgb.avi PoseNet model: 101 frame_path: ./temp/frame0010.jpg
# WARNING:tensorflow:From ../posenet-python/posenet/model.py:45: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# WARNING:tensorflow:From ../posenet-python/posenet/model.py:46: The name tf.GraphDef is deprecated. Please use tf.compat.v1.GraphDef instead.
# ../posenet-python/posenet/converter/config.py:9: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   cfg = yaml.load(cfg_f)

# %%
import sys
sys.path
# Out:
# ['',
#  '../posenet-python/',
#  '/usr/lib/python36.zip',
#  '/usr/lib/python3.6',
#  '/usr/lib/python3.6/lib-dynload',
#  '/data/students_home/amoscatelli/.local/lib/python3.6/site-packages',
#  '/data/students_home/amoscatelli/Desktop/actionAnalysis/detectron2_repo',
#  '/usr/local/lib/python3.6/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/lib/python3/dist-packages/IPython/extensions',
#  '/data/students_home/amoscatelli/.ipython']

# %%
# sys.path.remove('../posenet-python/')

# %%
from IPython.display import Image
Image("./temp/frame0031.jpg")

# %%
# !nvidia-smi
# Out:
# Tue Dec 10 21:03:57 2019
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 430.50       Driver Version: 430.50       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Quadro K600         Off  | 00000000:02:00.0  On |                  N/A |
# | 29%   59C    P8    N/A /  N/A |    111MiB /   980MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   1  GeForce GTX TIT...  Off  | 00000000:03:00.0 Off |                  N/A |
# | 57%   84C    P2   235W / 250W |  12212MiB / 12212MiB |     92%      Default |
# +-------------------------------+----------------------+----------------------+
# |   2  GeForce GTX TIT...  Off  | 00000000:81:00.0 Off |                  N/A |
# | 22%   56C    P8    18W / 250W |    112MiB / 12212MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |    0     16802      G   /usr/lib/xorg/Xorg                            99MiB |
# |    1     19471      C   /usr/bin/python3                            2152MiB |
# |    1     20173      C   python                                      9780MiB |
# |    1     24313      C   /usr/bin/python3                             265MiB |
# |    2     20173      C   python                                        99MiB |
# +-----------------------------------------------------------------------------+
